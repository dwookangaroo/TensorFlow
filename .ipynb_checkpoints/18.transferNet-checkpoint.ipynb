# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import optimizers, \
                                         metrics, Input, models, layers
from tensorflow.keras.models import Sequential
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
b_size = 5
train_datagen = ImageDataGenerator(rescale=1./255,
                                              horizontal_flip=True,
                                               #수평 대칭 이미지를 50% 확률로 만듬
                                              width_shift_range=0.1,
                                              # 전체 크기의 10% 범위에서 좌우로 이동
                                               height_shift_range=0.1,
                                   fill_mode='nearest'
                                              )

train_generator = train_datagen.flow_from_directory(
                                                                'train', # 폴더명
                                                                 target_size=(150,150), 
                                                                batch_size=b_size,
                                                                class_mode='binary')

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
                                                                'test', # 폴더명
                                                                 target_size=(150,150), 
                                                                batch_size=b_size,
                                                                class_mode='binary')
# Out:
# Found 160 images belonging to 2 classes.
# Found 120 images belonging to 2 classes.

# %%
transfer_model = VGG16(weights='imagenet', include_top=False, 
                       #include_top - fc layer을 뺏다
                       # 
                      input_shape=(150,150,3))
transfer_model.trainable=False
transfer_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 13s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
finetune_model = Sequential()
finetune_model.add(transfer_model) # 4X4 가 들어옴
finetune_model.add(Flatten()) # Dense층으로 집어넣어야하기때문에 펼처준다
finetune_model.add(Dense(64, activation='relu'))
finetune_model.add(Dense(2, activation='softmax'))
finetune_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 4, 4, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                524352
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 15,239,170
# Trainable params: 524,482
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
finetune_model.compile(loss='sparse_categorical_crossentropy', \
                              optimizer=optimizers.Adam(\
                                                       learning_rate=0.0002), metrics=['accuracy'])

steps_train = len(train_generator)
steps_test = len(test_generator)

history = finetune_model.fit(
       train_generator,
       steps_per_epoch=steps_train,
       epochs=20,
       validation_data=test_generator,
       validation_steps=steps_test )
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
y_vloss = history.history['val_loss']
y_loss = history.history['loss']
x_len = np.arange(len(y_loss))
plt.plot(x_len, acc, marker='.', c='cornflowerblue', label='Trainset_acc')
plt.plot(x_len, val_acc, marker='.', c='blue', label='Testset_acc')
plt.plot(x_len, y_vloss, marker='.', c='red', label='Testset_loss')
plt.plot(x_len, y_loss, marker='.', c='lightcoral', label='Trainset_loss')
plt.legend(loc='upper left')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss/acc')
plt.show()
# Out:
# Epoch 1/20
# 32/32 [==============================] - 34s 1s/step - loss: 0.6150 - accuracy: 0.6687 - val_loss: 0.4799 - val_accuracy: 0.7917
# Epoch 2/20
# 32/32 [==============================] - 31s 979ms/step - loss: 0.3929 - accuracy: 0.8875 - val_loss: 0.3880 - val_accuracy: 0.8250
# Epoch 3/20
# 32/32 [==============================] - 35s 1s/step - loss: 0.2988 - accuracy: 0.9125 - val_loss: 0.3090 - val_accuracy: 0.8833
# Epoch 4/20
# 32/32 [==============================] - 34s 1s/step - loss: 0.2708 - accuracy: 0.9062 - val_loss: 0.2669 - val_accuracy: 0.8917
# Epoch 5/20
# 32/32 [==============================] - 34s 1s/step - loss: 0.2200 - accuracy: 0.9500 - val_loss: 0.2692 - val_accuracy: 0.8833
# Epoch 6/20
# 32/32 [==============================] - 35s 1s/step - loss: 0.1726 - accuracy: 0.9500 - val_loss: 0.1801 - val_accuracy: 0.9500
# Epoch 7/20
# 32/32 [==============================] - 61s 2s/step - loss: 0.1547 - accuracy: 0.9750 - val_loss: 0.1601 - val_accuracy: 0.9667
# Epoch 8/20
# 32/32 [==============================] - 82s 3s/step - loss: 0.1294 - accuracy: 0.9812 - val_loss: 0.1694 - val_accuracy: 0.9333
# Epoch 9/20
# 32/32 [==============================] - 73s 2s/step - loss: 0.1296 - accuracy: 0.9750 - val_loss: 0.1523 - val_accuracy: 0.9583
# Epoch 10/20
# 32/32 [==============================] - 30s 947ms/step - loss: 0.1248 - accuracy: 0.9688 - val_loss: 0.1569 - val_accuracy: 0.9417
# Epoch 11/20
# 32/32 [==============================] - 129s 4s/step - loss: 0.1153 - accuracy: 0.9688 - val_loss: 0.1295 - val_accuracy: 0.9583
# Epoch 12/20
# 32/32 [==============================] - 59s 2s/step - loss: 0.1102 - accuracy: 0.9750 - val_loss: 0.1277 - val_accuracy: 0.9500
# Epoch 13/20
# 32/32 [==============================] - 103s 3s/step - loss: 0.0997 - accuracy: 0.9563 - val_loss: 0.1179 - val_accuracy: 0.9583
# Epoch 14/20
# 32/32 [==============================] - 73s 2s/step - loss: 0.0872 - accuracy: 0.9688 - val_loss: 0.1146 - val_accuracy: 0.9583
# Epoch 15/20
# 32/32 [==============================] - 66s 2s/step - loss: 0.1113 - accuracy: 0.9563 - val_loss: 0.1287 - val_accuracy: 0.9500
# Epoch 16/20
# 32/32 [==============================] - 69s 2s/step - loss: 0.0895 - accuracy: 0.9688 - val_loss: 0.1261 - val_accuracy: 0.9583
# Epoch 17/20
# 32/32 [==============================] - 96s 3s/step - loss: 0.0959 - accuracy: 0.9625 - val_loss: 0.1535 - val_accuracy: 0.9333
# Epoch 18/20
# 32/32 [==============================] - 81s 3s/step - loss: 0.0938 - accuracy: 0.9688 - val_loss: 0.1750 - val_accuracy: 0.9250
# Epoch 19/20
# 32/32 [==============================] - 31s 979ms/step - loss: 0.0955 - accuracy: 0.9563 - val_loss: 0.0874 - val_accuracy: 0.9750
# Epoch 20/20
# 32/32 [==============================] - 45s 1s/step - loss: 0.0750 - accuracy: 0.9875 - val_loss: 0.0976 - val_accuracy: 0.9667
