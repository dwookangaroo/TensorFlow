# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Flatten, Input, Dropout, Reshape,\
                                                BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D

# 데이터셋
from tensorflow.keras.datasets import mnist
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.utils import to_categorical

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
import os
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")

# %%
generator = Sequential()   # 모델 이름을 generator로 정하고 Sequential() 함수를 호출

generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2))) # 0보다 작을경우 0.2를 곱해주라
# Input_dim=100은 100차원 크기의 랜덤 벡터를 준비해 집어넣으라는 뜻

generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D()) 
generator.add(Conv2D(64, kernel_size=5, padding='same')) # 64개의 그림 5X5
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh')) #출력 1개. 픽셀의 값을 -1에서 1사이

# %%
generator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6272)              633472
# _________________________________________________________________
# batch_normalization (BatchNo (None, 6272)              25088
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 128)         0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 14, 14, 64)        204864
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 14, 14, 64)        0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 1)         1601
# =================================================================
# Total params: 865,281
# Trainable params: 852,609
# Non-trainable params: 12,672
# _________________________________________________________________

# %%
# 모델 이름을 discriminator로 정하고 Sequential() 함수 호출
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same")) # 2칸씩 이동
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3)) 
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2))) 
discriminator.add(Dropout(0.3))
discriminator.add(Flatten()) # 가로세로 2차원을 1차원으로 바꾸어줌
discriminator.add(Dense(1, activation='sigmoid')) # 진짜(1) or 가짜(0) - sigmoid
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False # 판별이 끝나고 나면 판별자 자신이 학습되지 않게끔 학습 기능을 꺼줍니다

# %%
discriminator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 14, 14, 64)        1664
# _________________________________________________________________
# activation_1 (Activation)    (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 128)         204928
# _________________________________________________________________
# activation_2 (Activation)    (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6273
# =================================================================
# Total params: 212,865
# Trainable params: 0
# Non-trainable params: 212,865
# _________________________________________________________________

# %%
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput)) 
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')

# %%
gan.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________

# %%
def gan_train(epoch, batch_size, saving_interval):
    (X_train, _), (_, _) = mnist.load_data()  #train 데이터만 필요
    X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).\
                                                                    astype('float32')
    X_train = (X_train - 127.5) / 127.5 #(-1에서 1사이)
    true = np.ones((batch_size, 1))
    fake = np.zeros((batch_size, 1))
    
    for i in range(epoch):
        idx = np.random.randint(0, X_train.shape[0], batch_size)  #0부터 전체 샘플갯수중에, 배치사이즈 갯수만큼 뽑음
        imgs = X_train[idx]
        d_loss_real = discriminator.train_on_batch(imgs, true) #train_on_batch함수 - 학습을 시킨다
        
        
        noise = np.random.normal(0, 1, (batch_size, 100)) #0과 1사이로 정기분표형태로 난수발생
        gen_imgs = generator.predict(noise)
        d_loss_fake = discriminator.train_on_batch(gen_imgs, fake) # 가짜이다
        
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) # 평균오차
        g_loss = gan.train_on_batch(noise, true) #손실 계산.  gan안에는 discriminator가 들어가잇다
        # noise가 트루라고 여기고 실행을하는데 true가 아니기에 손실을 계산해준다
        # 여기선 discriminate 학습 X, generator 학습 o
        
        print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, \
                     ' g_loss:%.4f' % g_loss)
        
        if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("gan_images/gan_mnist_%d.png" % i)

# %%
gan_train(4001, 32, 200)

#결과 discriminate 손실은 줄어들고있다
# Out:
# epoch:0  d_loss:0.7115  g_loss:0.5308
# epoch:1  d_loss:0.5135  g_loss:0.2093
# epoch:2  d_loss:0.4955  g_loss:0.0658
# epoch:3  d_loss:0.5080  g_loss:0.0479
# epoch:4  d_loss:0.4971  g_loss:0.0886
# epoch:5  d_loss:0.4656  g_loss:0.2216
# epoch:6  d_loss:0.4460  g_loss:0.4230
# epoch:7  d_loss:0.4412  g_loss:0.6155
# epoch:8  d_loss:0.4429  g_loss:0.7328
# epoch:9  d_loss:0.4389  g_loss:0.8090
# epoch:10  d_loss:0.4388  g_loss:0.8648
# epoch:11  d_loss:0.5115  g_loss:0.9203
# epoch:12  d_loss:0.6538  g_loss:0.7944
# epoch:13  d_loss:0.7246  g_loss:0.6515
# epoch:14  d_loss:0.6890  g_loss:0.4151
# epoch:15  d_loss:0.5158  g_loss:0.2236
# epoch:16  d_loss:0.3550  g_loss:0.1293
# epoch:17  d_loss:0.2685  g_loss:0.0681
# epoch:18  d_loss:0.1811  g_loss:0.0403
# epoch:19  d_loss:0.1296  g_loss:0.0284
# epoch:20  d_loss:0.0873  g_loss:0.0260
# epoch:21  d_loss:0.0646  g_loss:0.0318
# epoch:22  d_loss:0.0469  g_loss:0.1332
# epoch:23  d_loss:0.0475  g_loss:0.2450
# epoch:24  d_loss:0.0825  g_loss:0.0982
# epoch:25  d_loss:0.1415  g_loss:0.6391
# epoch:26  d_loss:0.5429  g_loss:0.4889
# epoch:27  d_loss:0.5561  g_loss:1.3325
# epoch:28  d_loss:1.4345  g_loss:0.5598
# epoch:29  d_loss:1.3889  g_loss:0.5269
# epoch:30  d_loss:1.4155  g_loss:1.1988
# epoch:31  d_loss:1.8464  g_loss:0.9475
# epoch:32  d_loss:1.5201  g_loss:0.6022
# epoch:33  d_loss:1.1878  g_loss:0.4907
# epoch:34  d_loss:0.7480  g_loss:0.7187
# epoch:35  d_loss:0.4532  g_loss:1.4982
# epoch:36  d_loss:0.2805  g_loss:1.9605
# epoch:37  d_loss:0.2072  g_loss:2.4979
# epoch:38  d_loss:0.1865  g_loss:2.3971
# epoch:39  d_loss:0.0921  g_loss:2.2622
# epoch:40  d_loss:0.0656  g_loss:2.3001
# epoch:41  d_loss:0.0413  g_loss:2.3522
# epoch:42  d_loss:0.0349  g_loss:1.9928
# epoch:43  d_loss:0.0180  g_loss:2.3268
# epoch:44  d_loss:0.0387  g_loss:2.2255
# epoch:45  d_loss:0.0705  g_loss:2.2547
# epoch:46  d_loss:0.0182  g_loss:1.6972
# epoch:47  d_loss:0.0384  g_loss:2.2112
# epoch:48  d_loss:0.1366  g_loss:2.1268
# epoch:49  d_loss:0.1878  g_loss:3.4387
# epoch:50  d_loss:0.2383  g_loss:4.5830
# epoch:51  d_loss:0.1405  g_loss:4.7672
# epoch:52  d_loss:0.3056  g_loss:4.1209
# epoch:53  d_loss:0.3969  g_loss:3.5001
# epoch:54  d_loss:0.2485  g_loss:2.9136
# epoch:55  d_loss:0.4601  g_loss:3.3257
# epoch:56  d_loss:0.4713  g_loss:2.7211
# epoch:57  d_loss:0.6802  g_loss:3.1686
# epoch:58  d_loss:0.3475  g_loss:3.8658
# epoch:59  d_loss:0.6137  g_loss:3.3194
# epoch:60  d_loss:0.3476  g_loss:2.5900
# epoch:61  d_loss:0.2739  g_loss:1.9208
# epoch:62  d_loss:0.3150  g_loss:1.7166
# epoch:63  d_loss:0.3824  g_loss:1.5622
# epoch:64  d_loss:0.3734  g_loss:1.8245
# epoch:65  d_loss:0.3371  g_loss:1.9770
# epoch:66  d_loss:0.2514  g_loss:2.2417
# epoch:67  d_loss:0.3656  g_loss:2.2433
# epoch:68  d_loss:0.3717  g_loss:1.6878
# epoch:69  d_loss:0.4723  g_loss:1.8149
# epoch:70  d_loss:0.2575  g_loss:2.1299
# epoch:71  d_loss:0.4064  g_loss:1.9859
# epoch:72  d_loss:0.3040  g_loss:2.0870
# epoch:73  d_loss:0.3652  g_loss:2.0788
# epoch:74  d_loss:0.2667  g_loss:1.9217
# epoch:75  d_loss:0.4715  g_loss:1.8170
# epoch:76  d_loss:0.3898  g_loss:1.9804
# epoch:77  d_loss:0.3687  g_loss:1.8869
# epoch:78  d_loss:0.3431  g_loss:2.3257
# epoch:79  d_loss:0.4274  g_loss:2.1950
# epoch:80  d_loss:0.4079  g_loss:2.2999
# epoch:81  d_loss:0.4729  g_loss:2.0818
# epoch:82  d_loss:0.4423  g_loss:1.8413
# epoch:83  d_loss:0.3081  g_loss:1.8277
# epoch:84  d_loss:0.3555  g_loss:1.8207
# epoch:85  d_loss:0.3682  g_loss:1.9476
# epoch:86  d_loss:0.3200  g_loss:1.9732
# epoch:87  d_loss:0.3431  g_loss:2.2821
# epoch:88  d_loss:0.5754  g_loss:1.9285
# epoch:89  d_loss:0.3792  g_loss:2.4710
# epoch:90  d_loss:0.3952  g_loss:2.1613
# epoch:91  d_loss:0.4297  g_loss:2.0264
# epoch:92  d_loss:0.4290  g_loss:1.8580
# epoch:93  d_loss:0.3561  g_loss:1.7451
# epoch:94  d_loss:0.3857  g_loss:1.9123
# epoch:95  d_loss:0.4083  g_loss:2.0647
# epoch:96  d_loss:0.3888  g_loss:2.1214
# epoch:97  d_loss:0.4284  g_loss:1.6546
# epoch:98  d_loss:0.4602  g_loss:1.4672
# epoch:99  d_loss:0.3953  g_loss:1.6294
# epoch:100  d_loss:0.4552  g_loss:1.6674
# epoch:101  d_loss:0.4237  g_loss:1.6209
# epoch:102  d_loss:0.4582  g_loss:1.5211
# epoch:103  d_loss:0.4185  g_loss:1.6246
# epoch:104  d_loss:0.3685  g_loss:1.6929
# epoch:105  d_loss:0.3805  g_loss:1.6744
# epoch:106  d_loss:0.4589  g_loss:1.3630
# epoch:107  d_loss:0.4353  g_loss:1.3762
# epoch:108  d_loss:0.3533  g_loss:1.8319
# epoch:109  d_loss:0.4146  g_loss:1.6848
# epoch:110  d_loss:0.4269  g_loss:1.8250
# epoch:111  d_loss:0.3504  g_loss:1.8223
# epoch:112  d_loss:0.5124  g_loss:1.8083
# epoch:113  d_loss:0.4303  g_loss:1.7336
# epoch:114  d_loss:0.4529  g_loss:1.5416
# epoch:115  d_loss:0.5111  g_loss:1.6074
# epoch:116  d_loss:0.4571  g_loss:1.8591
# epoch:117  d_loss:0.5826  g_loss:1.7101
# epoch:118  d_loss:0.6832  g_loss:1.4360
# epoch:119  d_loss:0.5140  g_loss:1.6654
# epoch:120  d_loss:0.5431  g_loss:1.6765
# epoch:121  d_loss:0.6176  g_loss:1.5937
# epoch:122  d_loss:0.5814  g_loss:1.4866
# epoch:123  d_loss:0.6157  g_loss:1.4750
# epoch:124  d_loss:0.4773  g_loss:1.8409
# epoch:125  d_loss:0.5264  g_loss:1.4328
# epoch:126  d_loss:0.6605  g_loss:1.4671
# epoch:127  d_loss:0.6595  g_loss:1.3641
# epoch:128  d_loss:0.5719  g_loss:1.3641
# epoch:129  d_loss:0.7123  g_loss:1.5078
# epoch:130  d_loss:0.6227  g_loss:1.2737
# epoch:131  d_loss:0.5853  g_loss:1.3395
# epoch:132  d_loss:0.6667  g_loss:1.5107
# epoch:133  d_loss:0.7430  g_loss:1.1911
# epoch:134  d_loss:0.6419  g_loss:1.2759
# epoch:135  d_loss:0.7278  g_loss:1.1412
# epoch:136  d_loss:0.6766  g_loss:1.1666
# epoch:137  d_loss:0.6499  g_loss:1.1728
# epoch:138  d_loss:0.6733  g_loss:1.0659
# epoch:139  d_loss:0.4989  g_loss:1.1020
# epoch:140  d_loss:0.6572  g_loss:1.0443
# epoch:141  d_loss:0.5392  g_loss:1.1326
# epoch:142  d_loss:0.5964  g_loss:1.3736
# epoch:143  d_loss:0.6333  g_loss:1.1555
# epoch:144  d_loss:0.7599  g_loss:1.1847
# epoch:145  d_loss:0.6770  g_loss:1.1833
# epoch:146  d_loss:0.6378  g_loss:1.2881
# epoch:147  d_loss:0.6325  g_loss:1.5332
# epoch:148  d_loss:0.7550  g_loss:1.4133
# epoch:149  d_loss:0.8459  g_loss:1.2796
# epoch:150  d_loss:0.6392  g_loss:1.2464
# epoch:151  d_loss:0.5449  g_loss:1.4932
# epoch:152  d_loss:0.7089  g_loss:1.3761
# epoch:153  d_loss:0.5917  g_loss:1.4761
# epoch:154  d_loss:0.6257  g_loss:1.4637
# epoch:155  d_loss:0.7081  g_loss:1.3820
# epoch:156  d_loss:0.6288  g_loss:1.2276
# epoch:157  d_loss:0.6904  g_loss:1.1804
# epoch:158  d_loss:0.6056  g_loss:1.2152
# epoch:159  d_loss:0.4635  g_loss:1.5181
# epoch:160  d_loss:0.5132  g_loss:1.3278
# epoch:161  d_loss:0.5456  g_loss:1.3307
# epoch:162  d_loss:0.4502  g_loss:1.2977
# epoch:163  d_loss:0.4970  g_loss:1.2314
# epoch:164  d_loss:0.6180  g_loss:1.0456
# epoch:165  d_loss:0.5313  g_loss:0.8933
# epoch:166  d_loss:0.5755  g_loss:0.9569
# epoch:167  d_loss:0.5753  g_loss:1.1238
# epoch:168  d_loss:0.6120  g_loss:0.9803
# epoch:169  d_loss:0.7091  g_loss:0.7609
# epoch:170  d_loss:0.7113  g_loss:0.8138
# epoch:171  d_loss:0.7223  g_loss:0.7620
# epoch:172  d_loss:0.6488  g_loss:0.7707
# epoch:173  d_loss:0.8370  g_loss:0.7430
# epoch:174  d_loss:0.6155  g_loss:0.8231
# epoch:175  d_loss:0.6690  g_loss:1.0771
# epoch:176  d_loss:0.4453  g_loss:1.4694
# epoch:177  d_loss:0.4007  g_loss:1.8890
# epoch:178  d_loss:0.3767  g_loss:2.2646
# epoch:179  d_loss:0.5557  g_loss:2.8034
# epoch:180  d_loss:0.4030  g_loss:2.7312
# epoch:181  d_loss:0.5589  g_loss:2.3954
# epoch:182  d_loss:0.5795  g_loss:2.2571
# epoch:183  d_loss:0.7637  g_loss:1.9890
# epoch:184  d_loss:0.9279  g_loss:1.3879
# epoch:185  d_loss:0.8838  g_loss:1.2284
# epoch:186  d_loss:1.1862  g_loss:1.0213
# epoch:187  d_loss:0.8426  g_loss:1.0545
# epoch:188  d_loss:0.7833  g_loss:1.0723
# epoch:189  d_loss:0.8467  g_loss:1.1526
# epoch:190  d_loss:0.8250  g_loss:1.2658
# epoch:191  d_loss:0.5943  g_loss:1.3467
# epoch:192  d_loss:0.4230  g_loss:1.3951
# epoch:193  d_loss:0.4585  g_loss:1.7424
# epoch:194  d_loss:0.4278  g_loss:1.4991
# epoch:195  d_loss:0.3801  g_loss:1.8819
# epoch:196  d_loss:0.2912  g_loss:1.9979
# epoch:197  d_loss:0.3107  g_loss:2.0415
# epoch:198  d_loss:0.3404  g_loss:2.0885
# epoch:199  d_loss:0.3083  g_loss:2.1041
# epoch:200  d_loss:0.2623  g_loss:2.1617
# epoch:201  d_loss:0.2710  g_loss:2.2250
# epoch:202  d_loss:0.2771  g_loss:2.2850
# epoch:203  d_loss:0.2923  g_loss:2.3585
# epoch:204  d_loss:0.3659  g_loss:1.9913
# epoch:205  d_loss:0.2660  g_loss:2.3551
# epoch:206  d_loss:0.3001  g_loss:2.1278
# epoch:207  d_loss:0.5073  g_loss:1.7103
# epoch:208  d_loss:0.4101  g_loss:1.9370
# epoch:209  d_loss:0.4194  g_loss:1.8326
# epoch:210  d_loss:0.6304  g_loss:1.5078
# epoch:211  d_loss:0.5342  g_loss:1.4884
# epoch:212  d_loss:0.7401  g_loss:1.0720
# epoch:213  d_loss:0.5705  g_loss:1.4110
# epoch:214  d_loss:0.7038  g_loss:1.3788
# epoch:215  d_loss:0.8400  g_loss:1.1344
# epoch:216  d_loss:0.8329  g_loss:0.8158
# epoch:217  d_loss:0.7909  g_loss:0.9878
# epoch:218  d_loss:0.8747  g_loss:0.8627
# epoch:219  d_loss:0.8164  g_loss:0.7914
# epoch:220  d_loss:0.8397  g_loss:0.9171
# epoch:221  d_loss:0.7568  g_loss:0.9195
# epoch:222  d_loss:0.7917  g_loss:0.9574
# epoch:223  d_loss:0.7465  g_loss:1.1033
# epoch:224  d_loss:0.6808  g_loss:1.0001
# epoch:225  d_loss:0.5880  g_loss:1.2361
# epoch:226  d_loss:0.4903  g_loss:1.3707
# epoch:227  d_loss:0.3916  g_loss:1.9278
# epoch:228  d_loss:0.4186  g_loss:2.5326
# epoch:229  d_loss:0.2341  g_loss:3.1293
# epoch:230  d_loss:0.2706  g_loss:3.0926
# epoch:231  d_loss:0.1702  g_loss:3.5973
# epoch:232  d_loss:0.2373  g_loss:2.9102
# epoch:233  d_loss:0.1468  g_loss:3.8219
# epoch:234  d_loss:0.1567  g_loss:3.6969
# epoch:235  d_loss:0.3075  g_loss:3.9178
# epoch:236  d_loss:0.2094  g_loss:3.5670
# epoch:237  d_loss:0.2581  g_loss:3.9900
# epoch:238  d_loss:0.3790  g_loss:4.1132
# epoch:239  d_loss:0.8452  g_loss:2.6307
# epoch:240  d_loss:1.0471  g_loss:2.4499
# epoch:241  d_loss:0.6324  g_loss:2.3707
# epoch:242  d_loss:0.8705  g_loss:2.8363
# epoch:243  d_loss:1.2209  g_loss:1.9963
# epoch:244  d_loss:1.0534  g_loss:1.4818
# epoch:245  d_loss:1.0532  g_loss:1.1526
# epoch:246  d_loss:0.8103  g_loss:1.2957
# epoch:247  d_loss:0.7168  g_loss:1.3026
# epoch:248  d_loss:0.6220  g_loss:1.7413
# epoch:249  d_loss:0.6450  g_loss:1.9236
# epoch:250  d_loss:0.6030  g_loss:2.1765
# epoch:251  d_loss:0.6991  g_loss:1.8706
# epoch:252  d_loss:0.5907  g_loss:1.7344
# epoch:253  d_loss:0.6054  g_loss:1.6789
# epoch:254  d_loss:0.4940  g_loss:1.5780
# epoch:255  d_loss:0.4837  g_loss:1.6213
# epoch:256  d_loss:0.4379  g_loss:1.7140
# epoch:257  d_loss:0.4320  g_loss:1.8645
# epoch:258  d_loss:0.4015  g_loss:1.9680
# epoch:259  d_loss:0.4488  g_loss:1.9085
# epoch:260  d_loss:0.4425  g_loss:1.8372
# epoch:261  d_loss:0.3864  g_loss:1.9667
# epoch:262  d_loss:0.3380  g_loss:1.9779
# epoch:263  d_loss:0.4041  g_loss:1.9607
# epoch:264  d_loss:0.3839  g_loss:1.8107
# epoch:265  d_loss:0.3858  g_loss:2.0370
# epoch:266  d_loss:0.3744  g_loss:2.1403
# epoch:267  d_loss:0.4919  g_loss:1.8918
# epoch:268  d_loss:0.3598  g_loss:1.9459
# epoch:269  d_loss:0.4005  g_loss:2.0611
# epoch:270  d_loss:0.5478  g_loss:1.9161
# epoch:271  d_loss:0.4914  g_loss:1.8393
# epoch:272  d_loss:0.4034  g_loss:2.0195
# epoch:273  d_loss:0.4473  g_loss:1.8022
# epoch:274  d_loss:0.4127  g_loss:1.8538
# epoch:275  d_loss:0.4293  g_loss:1.6995
# epoch:276  d_loss:0.4675  g_loss:1.5791
# epoch:277  d_loss:0.4897  g_loss:1.6409
# epoch:278  d_loss:0.4410  g_loss:1.6529
# epoch:279  d_loss:0.5877  g_loss:1.7645
# epoch:280  d_loss:0.6518  g_loss:1.2535
# epoch:281  d_loss:0.4731  g_loss:1.3291
# epoch:282  d_loss:0.5305  g_loss:1.3723
# epoch:283  d_loss:0.4512  g_loss:1.3229
# epoch:284  d_loss:0.5723  g_loss:1.2755
# epoch:285  d_loss:0.4640  g_loss:1.3317
# epoch:286  d_loss:0.5342  g_loss:1.3402
# epoch:287  d_loss:0.5502  g_loss:1.3227
# epoch:288  d_loss:0.4889  g_loss:1.2911
# epoch:289  d_loss:0.5290  g_loss:1.3582
# epoch:290  d_loss:0.4937  g_loss:1.2300
# epoch:291  d_loss:0.5185  g_loss:1.1845
# epoch:292  d_loss:0.4408  g_loss:1.4752
# epoch:293  d_loss:0.5146  g_loss:1.2368
# epoch:294  d_loss:0.4875  g_loss:1.2624
# epoch:295  d_loss:0.4202  g_loss:1.2528
# epoch:296  d_loss:0.5361  g_loss:1.5361
# epoch:297  d_loss:0.5414  g_loss:1.5793
# epoch:298  d_loss:0.4904  g_loss:1.4589
# epoch:299  d_loss:0.5433  g_loss:1.7347
# epoch:300  d_loss:0.4434  g_loss:1.7255
# epoch:301  d_loss:0.4214  g_loss:2.0326
# epoch:302  d_loss:0.4100  g_loss:1.8460
# epoch:303  d_loss:0.4071  g_loss:2.0867
# epoch:304  d_loss:0.5998  g_loss:2.2291
# epoch:305  d_loss:0.3952  g_loss:2.3264
# epoch:306  d_loss:0.4119  g_loss:2.1652
# epoch:307  d_loss:0.5400  g_loss:1.9227
# epoch:308  d_loss:0.4508  g_loss:2.2963
# epoch:309  d_loss:0.4538  g_loss:2.1265
# epoch:310  d_loss:0.5332  g_loss:1.7102
# epoch:311  d_loss:0.5207  g_loss:1.6524
# epoch:312  d_loss:0.4777  g_loss:2.0532
# epoch:313  d_loss:0.5422  g_loss:1.6246
# epoch:314  d_loss:0.5535  g_loss:1.4788
# epoch:315  d_loss:0.6554  g_loss:1.5181
# epoch:316  d_loss:0.5462  g_loss:1.6073
# epoch:317  d_loss:0.5061  g_loss:1.5452
# epoch:318  d_loss:0.6076  g_loss:1.1467
# epoch:319  d_loss:0.4654  g_loss:1.5737
# epoch:320  d_loss:0.5599  g_loss:1.3246
# epoch:321  d_loss:0.5052  g_loss:1.3920
# epoch:322  d_loss:0.4703  g_loss:1.3728
# epoch:323  d_loss:0.5636  g_loss:1.4442
# epoch:324  d_loss:0.4649  g_loss:1.3306
# epoch:325  d_loss:0.6349  g_loss:1.1770
# epoch:326  d_loss:0.6208  g_loss:1.1817
# epoch:327  d_loss:0.4964  g_loss:1.3520
# epoch:328  d_loss:0.5894  g_loss:1.1388
# epoch:329  d_loss:0.5191  g_loss:1.2907
# epoch:330  d_loss:0.5030  g_loss:1.3033
# epoch:331  d_loss:0.5333  g_loss:1.4197
# epoch:332  d_loss:0.5338  g_loss:1.3121
# epoch:333  d_loss:0.5535  g_loss:1.2248
# epoch:334  d_loss:0.4041  g_loss:1.5323
# epoch:335  d_loss:0.5246  g_loss:1.5462
# epoch:336  d_loss:0.5538  g_loss:1.5816
# epoch:337  d_loss:0.4955  g_loss:1.3241
# epoch:338  d_loss:0.4554  g_loss:1.6488
# epoch:339  d_loss:0.4605  g_loss:1.4507
# epoch:340  d_loss:0.4026  g_loss:1.6153
# epoch:341  d_loss:0.3839  g_loss:1.6750
# epoch:342  d_loss:0.4206  g_loss:1.4253
# epoch:343  d_loss:0.5121  g_loss:1.3325
# epoch:344  d_loss:0.4460  g_loss:1.6196
# epoch:345  d_loss:0.4754  g_loss:1.6662
# epoch:346  d_loss:0.4900  g_loss:1.4953
# epoch:347  d_loss:0.4660  g_loss:1.6096
# epoch:348  d_loss:0.4719  g_loss:1.5620
# epoch:349  d_loss:0.3981  g_loss:1.6935
# epoch:350  d_loss:0.3479  g_loss:1.8867
# epoch:351  d_loss:0.3482  g_loss:1.8859
# epoch:352  d_loss:0.4545  g_loss:1.8737
# epoch:353  d_loss:0.4257  g_loss:1.6064
# epoch:354  d_loss:0.4075  g_loss:1.6484
# epoch:355  d_loss:0.4253  g_loss:1.8087
# epoch:356  d_loss:0.4130  g_loss:1.7982
# epoch:357  d_loss:0.4350  g_loss:1.6448
# epoch:358  d_loss:0.3998  g_loss:1.6173
# epoch:359  d_loss:0.5082  g_loss:1.5421
# epoch:360  d_loss:0.3969  g_loss:1.8622
# epoch:361  d_loss:0.3928  g_loss:1.9388
# epoch:362  d_loss:0.5341  g_loss:1.8565
# epoch:363  d_loss:0.4110  g_loss:1.7761
# epoch:364  d_loss:0.5182  g_loss:1.9632
# epoch:365  d_loss:0.5582  g_loss:1.6834
# epoch:366  d_loss:0.5012  g_loss:1.6990
# epoch:367  d_loss:0.4487  g_loss:1.5335
# epoch:368  d_loss:0.4849  g_loss:1.5187
# epoch:369  d_loss:0.4653  g_loss:1.6801
# epoch:370  d_loss:0.5167  g_loss:1.7536
# epoch:371  d_loss:0.5512  g_loss:1.9023
# epoch:372  d_loss:0.5989  g_loss:1.5404
# epoch:373  d_loss:0.6154  g_loss:1.3019
# epoch:374  d_loss:0.6887  g_loss:1.0592
# epoch:375  d_loss:0.6977  g_loss:0.8512
# epoch:376  d_loss:0.6444  g_loss:1.2793
# epoch:377  d_loss:0.6765  g_loss:1.3708
# epoch:378  d_loss:0.6313  g_loss:1.4070
# epoch:379  d_loss:0.6185  g_loss:1.4116
# epoch:380  d_loss:0.5561  g_loss:1.5468
# epoch:381  d_loss:0.5706  g_loss:1.3869
# epoch:382  d_loss:0.4590  g_loss:1.3747
# epoch:383  d_loss:0.5762  g_loss:1.2967
# epoch:384  d_loss:0.7001  g_loss:1.0749
# epoch:385  d_loss:0.5228  g_loss:1.1832
# epoch:386  d_loss:0.4474  g_loss:1.4516
# epoch:387  d_loss:0.5413  g_loss:1.5780
# epoch:388  d_loss:0.5766  g_loss:1.2860
# epoch:389  d_loss:0.6131  g_loss:1.3825
# epoch:390  d_loss:0.5097  g_loss:1.3924
# epoch:391  d_loss:0.5138  g_loss:1.4506
# epoch:392  d_loss:0.4955  g_loss:1.3053
# epoch:393  d_loss:0.5113  g_loss:1.5676
# epoch:394  d_loss:0.4611  g_loss:1.4668
# epoch:395  d_loss:0.5088  g_loss:1.5628
# epoch:396  d_loss:0.3742  g_loss:1.8078
# epoch:397  d_loss:0.4659  g_loss:1.7838
# epoch:398  d_loss:0.4821  g_loss:1.5314
# epoch:399  d_loss:0.4222  g_loss:1.7224
# epoch:400  d_loss:0.3362  g_loss:1.7121
# epoch:401  d_loss:0.3948  g_loss:1.7470
# epoch:402  d_loss:0.4658  g_loss:1.5416
# epoch:403  d_loss:0.3911  g_loss:1.8005
# epoch:404  d_loss:0.4303  g_loss:1.4202
# epoch:405  d_loss:0.4428  g_loss:1.8070
# epoch:406  d_loss:0.3121  g_loss:1.8703
# epoch:407  d_loss:0.3202  g_loss:1.8718
# epoch:408  d_loss:0.4054  g_loss:1.8590
# epoch:409  d_loss:0.3854  g_loss:1.8780
# epoch:410  d_loss:0.4448  g_loss:2.0004
# epoch:411  d_loss:0.3635  g_loss:1.8737
# epoch:412  d_loss:0.4095  g_loss:2.2574
# epoch:413  d_loss:0.5094  g_loss:1.8353
# epoch:414  d_loss:0.4481  g_loss:1.8212
# epoch:415  d_loss:0.2636  g_loss:1.9991
# epoch:416  d_loss:0.3965  g_loss:1.8854
# epoch:417  d_loss:0.5926  g_loss:1.7405
# epoch:418  d_loss:0.5681  g_loss:1.4313
# epoch:419  d_loss:0.4532  g_loss:1.4745
# epoch:420  d_loss:0.3845  g_loss:1.8284
# epoch:421  d_loss:0.5044  g_loss:2.0983
# epoch:422  d_loss:0.3542  g_loss:1.7594
# epoch:423  d_loss:0.3976  g_loss:1.8515
# epoch:424  d_loss:0.3400  g_loss:2.0320
# epoch:425  d_loss:0.3975  g_loss:1.6698
# epoch:426  d_loss:0.3826  g_loss:1.6119
# epoch:427  d_loss:0.4182  g_loss:1.8292
# epoch:428  d_loss:0.5178  g_loss:1.6407
# epoch:429  d_loss:0.3882  g_loss:1.6812
# epoch:430  d_loss:0.2762  g_loss:2.1254
# epoch:431  d_loss:0.3707  g_loss:2.2273
# epoch:432  d_loss:0.3013  g_loss:2.3630
# epoch:433  d_loss:0.2996  g_loss:2.2320
# epoch:434  d_loss:0.3069  g_loss:2.1069
# epoch:435  d_loss:0.4219  g_loss:2.1051
# epoch:436  d_loss:0.3741  g_loss:2.0296
# epoch:437  d_loss:0.3393  g_loss:2.2057
# epoch:438  d_loss:0.3481  g_loss:2.2132
# epoch:439  d_loss:0.2322  g_loss:2.8491
# epoch:440  d_loss:0.4570  g_loss:2.1508
# epoch:441  d_loss:0.4266  g_loss:2.1592
# epoch:442  d_loss:0.2853  g_loss:2.2703
# epoch:443  d_loss:0.3321  g_loss:1.8391
# epoch:444  d_loss:0.3787  g_loss:2.0612
# epoch:445  d_loss:0.3967  g_loss:1.9337
# epoch:446  d_loss:0.4244  g_loss:1.6637
# epoch:447  d_loss:0.4623  g_loss:2.1364
# epoch:448  d_loss:0.3836  g_loss:1.5771
# epoch:449  d_loss:0.5312  g_loss:1.7267
# epoch:450  d_loss:0.3645  g_loss:2.2008
# epoch:451  d_loss:0.2930  g_loss:2.4653
# epoch:452  d_loss:0.3377  g_loss:2.5075
# epoch:453  d_loss:0.5695  g_loss:1.5458
# epoch:454  d_loss:0.5409  g_loss:1.4451
# epoch:455  d_loss:0.4250  g_loss:1.5855
# epoch:456  d_loss:0.3707  g_loss:1.7074
# epoch:457  d_loss:0.4182  g_loss:2.1882
# epoch:458  d_loss:0.3919  g_loss:2.2346
# epoch:459  d_loss:0.4033  g_loss:1.7851
# epoch:460  d_loss:0.3624  g_loss:1.7734
# epoch:461  d_loss:0.4923  g_loss:1.8286
# epoch:462  d_loss:0.3960  g_loss:2.2472
# epoch:463  d_loss:0.2587  g_loss:2.3485
# epoch:464  d_loss:0.3154  g_loss:2.4196
# epoch:465  d_loss:0.3064  g_loss:1.7193
# epoch:466  d_loss:0.4296  g_loss:1.5285
# epoch:467  d_loss:0.3378  g_loss:1.7074
# epoch:468  d_loss:0.2678  g_loss:2.1721
# epoch:469  d_loss:0.2830  g_loss:2.4731
# epoch:470  d_loss:0.3563  g_loss:2.1648
# epoch:471  d_loss:0.3188  g_loss:2.0542
# epoch:472  d_loss:0.2703  g_loss:1.9653
# epoch:473  d_loss:0.3268  g_loss:1.7300
# epoch:474  d_loss:0.2809  g_loss:2.4408
# epoch:475  d_loss:0.3042  g_loss:2.3982
# epoch:476  d_loss:0.3619  g_loss:2.1315
# epoch:477  d_loss:0.3082  g_loss:2.5248
# epoch:478  d_loss:0.2680  g_loss:2.3233
# epoch:479  d_loss:0.2799  g_loss:2.2912
# epoch:480  d_loss:0.2313  g_loss:2.4667
# epoch:481  d_loss:0.2762  g_loss:2.5000
# epoch:482  d_loss:0.2920  g_loss:2.3247
# epoch:483  d_loss:0.1751  g_loss:2.4488
# epoch:484  d_loss:0.2419  g_loss:2.3186
# epoch:485  d_loss:0.2137  g_loss:2.2813
# epoch:486  d_loss:0.2323  g_loss:2.6590
# epoch:487  d_loss:0.2218  g_loss:2.4499
# epoch:488  d_loss:0.2084  g_loss:2.3782
# epoch:489  d_loss:0.2478  g_loss:2.4727
# epoch:490  d_loss:0.2709  g_loss:2.2262
# epoch:491  d_loss:0.2649  g_loss:2.4517
# epoch:492  d_loss:0.2648  g_loss:2.3081
# epoch:493  d_loss:0.2653  g_loss:2.3688
# epoch:494  d_loss:0.2382  g_loss:2.4525
# epoch:495  d_loss:0.2233  g_loss:2.7651
# epoch:496  d_loss:0.3157  g_loss:2.7819
# epoch:497  d_loss:0.3216  g_loss:2.9357
# epoch:498  d_loss:0.2312  g_loss:2.3538
# epoch:499  d_loss:0.4535  g_loss:1.7968
# epoch:500  d_loss:0.2785  g_loss:2.0526
# epoch:501  d_loss:0.2988  g_loss:2.1360
# epoch:502  d_loss:0.2331  g_loss:2.3382
# epoch:503  d_loss:0.3090  g_loss:2.5300
# epoch:504  d_loss:0.3157  g_loss:2.5225
# epoch:505  d_loss:0.3300  g_loss:2.1448
# epoch:506  d_loss:0.3762  g_loss:1.7541
# epoch:507  d_loss:0.3761  g_loss:1.7074
# epoch:508  d_loss:0.2864  g_loss:2.9386
# epoch:509  d_loss:0.2182  g_loss:3.1932
# epoch:510  d_loss:0.3623  g_loss:2.3328
# epoch:511  d_loss:0.3938  g_loss:2.1864
# epoch:512  d_loss:0.3942  g_loss:1.8940
# epoch:513  d_loss:0.2703  g_loss:1.8122
# epoch:514  d_loss:0.4497  g_loss:2.2240
# epoch:515  d_loss:0.1394  g_loss:2.8268
# epoch:516  d_loss:0.3233  g_loss:2.9055
# epoch:517  d_loss:0.3529  g_loss:2.4014
# epoch:518  d_loss:0.2998  g_loss:2.1491
# epoch:519  d_loss:0.2240  g_loss:2.4271
# epoch:520  d_loss:0.2171  g_loss:2.6337
# epoch:521  d_loss:0.3546  g_loss:2.4591
# epoch:522  d_loss:0.2803  g_loss:2.1099
# epoch:523  d_loss:0.3382  g_loss:1.8044
# epoch:524  d_loss:0.2794  g_loss:2.0459
# epoch:525  d_loss:0.2607  g_loss:1.9055
# epoch:526  d_loss:0.1643  g_loss:2.6219
# epoch:527  d_loss:0.2654  g_loss:2.4257
# epoch:528  d_loss:0.2219  g_loss:2.3512
# epoch:529  d_loss:0.2629  g_loss:2.2940
# epoch:530  d_loss:0.2541  g_loss:2.2500
# epoch:531  d_loss:0.2060  g_loss:2.4857
# epoch:532  d_loss:0.2774  g_loss:2.6183
# epoch:533  d_loss:0.1927  g_loss:2.3895
# epoch:534  d_loss:0.2371  g_loss:2.8528
# epoch:535  d_loss:0.2016  g_loss:2.5076
# epoch:536  d_loss:0.2066  g_loss:2.7846
# epoch:537  d_loss:0.1933  g_loss:2.6836
# epoch:538  d_loss:0.2471  g_loss:2.1439
# epoch:539  d_loss:0.3020  g_loss:2.2655
# epoch:540  d_loss:0.2888  g_loss:1.9945
# epoch:541  d_loss:0.2822  g_loss:2.0539
# epoch:542  d_loss:0.2224  g_loss:2.6592
# epoch:543  d_loss:0.2441  g_loss:2.8533
# epoch:544  d_loss:0.2977  g_loss:1.9060
# epoch:545  d_loss:0.2909  g_loss:2.2495
# epoch:546  d_loss:0.2401  g_loss:2.0476
# epoch:547  d_loss:0.2330  g_loss:2.3731
# epoch:548  d_loss:0.2221  g_loss:2.6421
# epoch:549  d_loss:0.3065  g_loss:2.4329
# epoch:550  d_loss:0.2589  g_loss:2.2938
# epoch:551  d_loss:0.3395  g_loss:1.5907
# epoch:552  d_loss:0.2891  g_loss:2.3199
# epoch:553  d_loss:0.2919  g_loss:2.5476
# epoch:554  d_loss:0.2324  g_loss:2.9693
# epoch:555  d_loss:0.2517  g_loss:2.7776
# epoch:556  d_loss:0.3182  g_loss:1.7683
# epoch:557  d_loss:0.2870  g_loss:2.0260
# epoch:558  d_loss:0.1330  g_loss:2.6564
# epoch:559  d_loss:0.1852  g_loss:3.2610
# epoch:560  d_loss:0.2355  g_loss:3.5114
# epoch:561  d_loss:0.2162  g_loss:3.0672
# epoch:562  d_loss:0.5277  g_loss:2.6889
# epoch:563  d_loss:0.2920  g_loss:1.9188
# epoch:564  d_loss:0.3357  g_loss:2.4598
# epoch:565  d_loss:0.2010  g_loss:3.9276
# epoch:566  d_loss:0.3033  g_loss:3.6890
# epoch:567  d_loss:0.2163  g_loss:3.5281
# epoch:568  d_loss:0.3678  g_loss:2.4086
# epoch:569  d_loss:0.4205  g_loss:1.5153
# epoch:570  d_loss:0.3256  g_loss:1.5001
# epoch:571  d_loss:0.3415  g_loss:2.0642
# epoch:572  d_loss:0.2579  g_loss:2.9427
# epoch:573  d_loss:0.3993  g_loss:2.5281
# epoch:574  d_loss:0.3981  g_loss:1.7003
# epoch:575  d_loss:0.4193  g_loss:1.6380
# epoch:576  d_loss:0.3071  g_loss:2.2340
# epoch:577  d_loss:0.3646  g_loss:2.9176
# epoch:578  d_loss:0.2233  g_loss:2.7018
# epoch:579  d_loss:0.3230  g_loss:1.9577
# epoch:580  d_loss:0.2589  g_loss:2.1459
# epoch:581  d_loss:0.1564  g_loss:2.3354
# epoch:582  d_loss:0.1132  g_loss:2.6817
# epoch:583  d_loss:0.2594  g_loss:2.5942
# epoch:584  d_loss:0.2888  g_loss:1.9059
# epoch:585  d_loss:0.2886  g_loss:2.4362
# epoch:586  d_loss:0.2549  g_loss:2.2183
# epoch:587  d_loss:0.3772  g_loss:1.7146
# epoch:588  d_loss:0.3746  g_loss:1.6989
# epoch:589  d_loss:0.3463  g_loss:2.1361
# epoch:590  d_loss:0.2780  g_loss:2.1844
# epoch:591  d_loss:0.4196  g_loss:2.0888
# epoch:592  d_loss:0.4965  g_loss:2.0162
# epoch:593  d_loss:0.5044  g_loss:1.2319
# epoch:594  d_loss:0.5303  g_loss:1.4790
# epoch:595  d_loss:0.6036  g_loss:1.4201
# epoch:596  d_loss:0.3420  g_loss:2.3349
# epoch:597  d_loss:0.3232  g_loss:2.9112
# epoch:598  d_loss:0.5108  g_loss:1.4556
# epoch:599  d_loss:0.3949  g_loss:1.3429
# epoch:600  d_loss:0.4147  g_loss:1.7903
# epoch:601  d_loss:0.2608  g_loss:2.9798
# epoch:602  d_loss:0.3295  g_loss:2.5266
# epoch:603  d_loss:0.3772  g_loss:1.4990
# epoch:604  d_loss:0.3832  g_loss:1.2991
# epoch:605  d_loss:0.3952  g_loss:1.4689
# epoch:606  d_loss:0.3620  g_loss:1.7944
# epoch:607  d_loss:0.4190  g_loss:2.1692
# epoch:608  d_loss:0.7037  g_loss:1.0739
# epoch:609  d_loss:0.5274  g_loss:0.9114
# epoch:610  d_loss:0.9341  g_loss:0.7260
# epoch:611  d_loss:0.8946  g_loss:0.9402
# epoch:612  d_loss:0.7339  g_loss:1.2834
# epoch:613  d_loss:0.9302  g_loss:1.0906
# epoch:614  d_loss:0.3645  g_loss:1.7898
# epoch:615  d_loss:0.4878  g_loss:2.4987
# epoch:616  d_loss:0.7122  g_loss:2.5381
# epoch:617  d_loss:0.2463  g_loss:2.0413
# epoch:618  d_loss:0.3059  g_loss:2.0794
# epoch:619  d_loss:0.3935  g_loss:1.9363
# epoch:620  d_loss:0.3136  g_loss:1.6176
# epoch:621  d_loss:0.2260  g_loss:2.1467
# epoch:622  d_loss:0.2970  g_loss:2.1764
# epoch:623  d_loss:0.2907  g_loss:2.7939
# epoch:624  d_loss:0.4481  g_loss:2.3676
# epoch:625  d_loss:0.2040  g_loss:2.8616
# epoch:626  d_loss:0.3975  g_loss:2.1356
# epoch:627  d_loss:0.6548  g_loss:1.7784
# epoch:628  d_loss:0.7096  g_loss:1.3264
# epoch:629  d_loss:0.7482  g_loss:1.2273
# epoch:630  d_loss:0.7348  g_loss:1.3179
# epoch:631  d_loss:0.8305  g_loss:1.5390
# epoch:632  d_loss:0.7628  g_loss:1.6322
# epoch:633  d_loss:0.7162  g_loss:1.3758
# epoch:634  d_loss:0.7910  g_loss:0.8389
# epoch:635  d_loss:0.7074  g_loss:0.7450
# epoch:636  d_loss:0.3864  g_loss:1.2112
# epoch:637  d_loss:0.6173  g_loss:1.6948
# epoch:638  d_loss:0.4086  g_loss:1.5780
# epoch:639  d_loss:0.6200  g_loss:1.7133
# epoch:640  d_loss:0.5201  g_loss:1.5090
# epoch:641  d_loss:0.6646  g_loss:1.1131
# epoch:642  d_loss:0.5777  g_loss:1.4086
# epoch:643  d_loss:0.6712  g_loss:1.6308
# epoch:644  d_loss:0.3167  g_loss:1.7040
# epoch:645  d_loss:0.4452  g_loss:1.8849
# epoch:646  d_loss:0.4484  g_loss:1.5525
# epoch:647  d_loss:0.4736  g_loss:1.4208
# epoch:648  d_loss:0.4541  g_loss:1.0807
# epoch:649  d_loss:0.5364  g_loss:1.4404
# epoch:650  d_loss:0.4718  g_loss:1.1358
# epoch:651  d_loss:0.7177  g_loss:1.6841
# epoch:652  d_loss:0.7464  g_loss:1.2900
# epoch:653  d_loss:0.8119  g_loss:1.2388
# epoch:654  d_loss:0.8950  g_loss:1.2901
# epoch:655  d_loss:0.7114  g_loss:1.3517
# epoch:656  d_loss:0.8061  g_loss:1.1748
# epoch:657  d_loss:0.6631  g_loss:1.0545
# epoch:658  d_loss:0.6808  g_loss:1.1859
# epoch:659  d_loss:0.5317  g_loss:1.5905
# epoch:660  d_loss:0.4673  g_loss:1.8579
# epoch:661  d_loss:0.2539  g_loss:2.2554
# epoch:662  d_loss:0.2267  g_loss:2.1715
# epoch:663  d_loss:0.4101  g_loss:2.0688
# epoch:664  d_loss:0.2835  g_loss:1.9541
# epoch:665  d_loss:0.3667  g_loss:1.7963
# epoch:666  d_loss:0.3959  g_loss:1.7673
# epoch:667  d_loss:0.3535  g_loss:2.0296
# epoch:668  d_loss:0.2379  g_loss:2.0330
# epoch:669  d_loss:0.2739  g_loss:3.2684
# epoch:670  d_loss:0.1465  g_loss:3.5431
# epoch:671  d_loss:0.1117  g_loss:4.1624
# epoch:672  d_loss:0.1087  g_loss:3.9028
# epoch:673  d_loss:0.1687  g_loss:3.8083
# epoch:674  d_loss:0.1857  g_loss:2.7420
# epoch:675  d_loss:0.3746  g_loss:2.2603
# epoch:676  d_loss:0.7726  g_loss:1.8199
# epoch:677  d_loss:1.1442  g_loss:1.6800
# epoch:678  d_loss:1.0304  g_loss:2.4383
# epoch:679  d_loss:0.5453  g_loss:2.4949
# epoch:680  d_loss:0.4366  g_loss:3.8055
# epoch:681  d_loss:0.5367  g_loss:3.8944
# epoch:682  d_loss:0.2619  g_loss:4.3804
# epoch:683  d_loss:0.4863  g_loss:4.4645
# epoch:684  d_loss:0.3959  g_loss:4.1815
# epoch:685  d_loss:0.5934  g_loss:3.4615
# epoch:686  d_loss:0.6026  g_loss:2.7847
# epoch:687  d_loss:0.3926  g_loss:2.1682
# epoch:688  d_loss:0.6344  g_loss:1.9264
# epoch:689  d_loss:0.6921  g_loss:1.7180
# epoch:690  d_loss:0.7488  g_loss:1.6341
# epoch:691  d_loss:0.7123  g_loss:1.9732
# epoch:692  d_loss:0.8597  g_loss:1.9477
# epoch:693  d_loss:0.6118  g_loss:1.5543
# epoch:694  d_loss:0.6176  g_loss:1.6967
# epoch:695  d_loss:0.4892  g_loss:1.7696
# epoch:696  d_loss:0.3509  g_loss:1.9416
# epoch:697  d_loss:0.3013  g_loss:2.3219
# epoch:698  d_loss:0.1608  g_loss:3.1604
# epoch:699  d_loss:0.2606  g_loss:3.0426
# epoch:700  d_loss:0.1006  g_loss:3.3265
# epoch:701  d_loss:0.1773  g_loss:3.7665
# epoch:702  d_loss:0.2170  g_loss:3.8700
# epoch:703  d_loss:0.3384  g_loss:3.3166
# epoch:704  d_loss:0.3489  g_loss:3.4018
# epoch:705  d_loss:0.4336  g_loss:2.9469
# epoch:706  d_loss:0.2649  g_loss:2.7852
# epoch:707  d_loss:0.3871  g_loss:2.8711
# epoch:708  d_loss:0.2033  g_loss:3.4399
# epoch:709  d_loss:0.5549  g_loss:2.9214
# epoch:710  d_loss:0.4228  g_loss:2.8802
# epoch:711  d_loss:0.5384  g_loss:2.4538
# epoch:712  d_loss:0.5966  g_loss:1.7912
# epoch:713  d_loss:0.4161  g_loss:1.9741
# epoch:714  d_loss:0.3807  g_loss:2.1142
# epoch:715  d_loss:0.2925  g_loss:2.6870
# epoch:716  d_loss:0.3673  g_loss:2.6231
# epoch:717  d_loss:0.3450  g_loss:2.7545
# epoch:718  d_loss:0.3556  g_loss:2.5521
# epoch:719  d_loss:0.2574  g_loss:2.2195
# epoch:720  d_loss:0.4159  g_loss:2.1245
# epoch:721  d_loss:0.4620  g_loss:2.0896
# epoch:722  d_loss:0.3194  g_loss:2.2012
# epoch:723  d_loss:0.3674  g_loss:2.9992
# epoch:724  d_loss:0.3343  g_loss:2.8606
# epoch:725  d_loss:0.3167  g_loss:2.1741
# epoch:726  d_loss:0.2869  g_loss:2.1273
# epoch:727  d_loss:0.5801  g_loss:1.7384
# epoch:728  d_loss:0.4614  g_loss:1.3184
# epoch:729  d_loss:0.3473  g_loss:1.6641
# epoch:730  d_loss:0.4189  g_loss:1.5116
# epoch:731  d_loss:0.4821  g_loss:1.4704
# epoch:732  d_loss:0.3338  g_loss:1.9018
# epoch:733  d_loss:0.3168  g_loss:1.6354
# epoch:734  d_loss:0.3231  g_loss:2.1191
# epoch:735  d_loss:0.3349  g_loss:1.9940
# epoch:736  d_loss:0.2933  g_loss:2.6001
# epoch:737  d_loss:0.2871  g_loss:2.3603
# epoch:738  d_loss:0.2391  g_loss:2.5289
# epoch:739  d_loss:0.2556  g_loss:2.1954
# epoch:740  d_loss:0.3359  g_loss:2.0538
# epoch:741  d_loss:0.2623  g_loss:2.4486
# epoch:742  d_loss:0.1577  g_loss:2.9820
# epoch:743  d_loss:0.1914  g_loss:3.4296
# epoch:744  d_loss:0.1667  g_loss:3.1039
# epoch:745  d_loss:0.1675  g_loss:3.1672
# epoch:746  d_loss:0.1891  g_loss:2.9308
# epoch:747  d_loss:0.2382  g_loss:2.4882
# epoch:748  d_loss:0.2628  g_loss:2.2908
# epoch:749  d_loss:0.2111  g_loss:2.4291
# epoch:750  d_loss:0.2093  g_loss:2.2584
# epoch:751  d_loss:0.3711  g_loss:2.2168
# epoch:752  d_loss:0.3814  g_loss:2.3386
# epoch:753  d_loss:0.4282  g_loss:2.1650
# epoch:754  d_loss:0.5465  g_loss:1.6354
# epoch:755  d_loss:0.4790  g_loss:1.8357
# epoch:756  d_loss:0.4890  g_loss:1.8184
# epoch:757  d_loss:0.4788  g_loss:1.6798
# epoch:758  d_loss:0.3608  g_loss:1.3000
# epoch:759  d_loss:0.3556  g_loss:1.3797
# epoch:760  d_loss:0.4632  g_loss:1.3958
# epoch:761  d_loss:0.3671  g_loss:1.6411
# epoch:762  d_loss:0.5051  g_loss:1.8975
# epoch:763  d_loss:0.3109  g_loss:1.7576
# epoch:764  d_loss:0.4180  g_loss:1.6444
# epoch:765  d_loss:0.2971  g_loss:1.7017
# epoch:766  d_loss:0.4018  g_loss:1.6843
# epoch:767  d_loss:0.3433  g_loss:1.9868
# epoch:768  d_loss:0.3255  g_loss:2.3175
# epoch:769  d_loss:0.3569  g_loss:2.6752
# epoch:770  d_loss:0.3914  g_loss:2.2309
# epoch:771  d_loss:0.3020  g_loss:2.2000
# epoch:772  d_loss:0.2892  g_loss:2.3848
# epoch:773  d_loss:0.2990  g_loss:2.5608
# epoch:774  d_loss:0.3135  g_loss:1.8425
# epoch:775  d_loss:0.2800  g_loss:2.2529
# epoch:776  d_loss:0.3015  g_loss:1.8629
# epoch:777  d_loss:0.3484  g_loss:2.0818
# epoch:778  d_loss:0.4069  g_loss:1.6515
# epoch:779  d_loss:0.3075  g_loss:1.8170
# epoch:780  d_loss:0.2289  g_loss:2.1182
# epoch:781  d_loss:0.3060  g_loss:1.7609
# epoch:782  d_loss:0.4645  g_loss:1.9097
# epoch:783  d_loss:0.2833  g_loss:2.1464
# epoch:784  d_loss:0.3560  g_loss:1.9054
# epoch:785  d_loss:0.4790  g_loss:1.9604
# epoch:786  d_loss:0.4229  g_loss:1.5918
# epoch:787  d_loss:0.3947  g_loss:1.3762
# epoch:788  d_loss:0.3944  g_loss:1.4396
# epoch:789  d_loss:0.4310  g_loss:1.2017
# epoch:790  d_loss:0.4237  g_loss:1.6642
# epoch:791  d_loss:0.3229  g_loss:2.1610
# epoch:792  d_loss:0.5337  g_loss:2.4977
# epoch:793  d_loss:0.4789  g_loss:1.8996
# epoch:794  d_loss:0.7835  g_loss:1.3835
# epoch:795  d_loss:0.3913  g_loss:1.6785
# epoch:796  d_loss:0.5279  g_loss:1.2768
# epoch:797  d_loss:0.5359  g_loss:1.0915
# epoch:798  d_loss:0.3621  g_loss:1.2965
# epoch:799  d_loss:0.4064  g_loss:1.6131
# epoch:800  d_loss:0.3487  g_loss:1.6472
# epoch:801  d_loss:0.4663  g_loss:1.0802
# epoch:802  d_loss:0.4406  g_loss:1.4781
# epoch:803  d_loss:0.5258  g_loss:1.4764
# epoch:804  d_loss:0.5546  g_loss:1.2435
# epoch:805  d_loss:0.4353  g_loss:1.1773
# epoch:806  d_loss:0.4292  g_loss:1.5465
# epoch:807  d_loss:0.4615  g_loss:1.6669
# epoch:808  d_loss:0.4611  g_loss:1.4532
# epoch:809  d_loss:0.4052  g_loss:1.3692
# epoch:810  d_loss:0.4359  g_loss:1.0891
# epoch:811  d_loss:0.4716  g_loss:1.3124
# epoch:812  d_loss:0.7484  g_loss:1.2170
# epoch:813  d_loss:0.5914  g_loss:0.9861
# epoch:814  d_loss:0.5824  g_loss:1.0628
# epoch:815  d_loss:0.5891  g_loss:1.1122
# epoch:816  d_loss:0.4697  g_loss:1.4035
# epoch:817  d_loss:0.5115  g_loss:1.5633
# epoch:818  d_loss:0.4786  g_loss:1.2757
# epoch:819  d_loss:0.5541  g_loss:1.1903
# epoch:820  d_loss:0.5612  g_loss:0.8619
# epoch:821  d_loss:0.5218  g_loss:0.8988
# epoch:822  d_loss:0.4895  g_loss:1.1630
# epoch:823  d_loss:0.5443  g_loss:1.2157
# epoch:824  d_loss:0.5721  g_loss:1.1120
# epoch:825  d_loss:0.5100  g_loss:1.4150
# epoch:826  d_loss:0.6326  g_loss:1.1093
# epoch:827  d_loss:0.6045  g_loss:1.0696
# epoch:828  d_loss:0.5443  g_loss:1.2780
# epoch:829  d_loss:0.4280  g_loss:1.8149
# epoch:830  d_loss:0.3800  g_loss:1.9431
# epoch:831  d_loss:0.4762  g_loss:1.9635
# epoch:832  d_loss:0.5933  g_loss:1.7473
# epoch:833  d_loss:0.4411  g_loss:1.6557
# epoch:834  d_loss:0.4550  g_loss:1.6166
# epoch:835  d_loss:0.4993  g_loss:1.6872
# epoch:836  d_loss:0.5383  g_loss:1.7268
# epoch:837  d_loss:0.6574  g_loss:1.5569
# epoch:838  d_loss:0.4455  g_loss:1.4912
# epoch:839  d_loss:0.4749  g_loss:1.3611
# epoch:840  d_loss:0.3404  g_loss:1.7128
# epoch:841  d_loss:0.5181  g_loss:1.5949
# epoch:842  d_loss:0.3627  g_loss:1.9030
# epoch:843  d_loss:0.2423  g_loss:2.0414
# epoch:844  d_loss:0.3779  g_loss:2.0775
# epoch:845  d_loss:0.3986  g_loss:2.0005
# epoch:846  d_loss:0.4242  g_loss:1.5518
# epoch:847  d_loss:0.5177  g_loss:1.4855
# epoch:848  d_loss:0.3385  g_loss:1.4089
# epoch:849  d_loss:0.4900  g_loss:1.9283
# epoch:850  d_loss:0.2710  g_loss:2.4213
# epoch:851  d_loss:0.3478  g_loss:2.6509
# epoch:852  d_loss:0.5407  g_loss:2.1229
# epoch:853  d_loss:0.5570  g_loss:1.4125
# epoch:854  d_loss:0.5131  g_loss:1.1423
# epoch:855  d_loss:0.4313  g_loss:1.3944
# epoch:856  d_loss:0.4738  g_loss:1.3936
# epoch:857  d_loss:0.3409  g_loss:1.7990
# epoch:858  d_loss:0.4840  g_loss:2.3273
# epoch:859  d_loss:0.5352  g_loss:1.6660
# epoch:860  d_loss:0.5005  g_loss:1.6991
# epoch:861  d_loss:0.5057  g_loss:1.3303
# epoch:862  d_loss:0.3332  g_loss:1.5426
# epoch:863  d_loss:0.3317  g_loss:1.8380
# epoch:864  d_loss:0.3894  g_loss:1.9713
# epoch:865  d_loss:0.3219  g_loss:2.2736
# epoch:866  d_loss:0.3173  g_loss:2.1201
# epoch:867  d_loss:0.2792  g_loss:2.2894
# epoch:868  d_loss:0.3010  g_loss:2.1205
# epoch:869  d_loss:0.2307  g_loss:2.6390
# epoch:870  d_loss:0.3561  g_loss:2.6198
# epoch:871  d_loss:0.3221  g_loss:2.5438
# epoch:872  d_loss:0.4205  g_loss:2.3671
# epoch:873  d_loss:0.3891  g_loss:2.1458
# epoch:874  d_loss:0.3588  g_loss:2.2578
# epoch:875  d_loss:0.3212  g_loss:2.6842
# epoch:876  d_loss:0.2642  g_loss:2.6749
# epoch:877  d_loss:0.4697  g_loss:2.5862
# epoch:878  d_loss:0.5786  g_loss:2.2046
# epoch:879  d_loss:0.3600  g_loss:2.0223
# epoch:880  d_loss:0.3574  g_loss:1.8344
# epoch:881  d_loss:0.3527  g_loss:2.3973
# epoch:882  d_loss:0.4526  g_loss:2.5069
# epoch:883  d_loss:0.6004  g_loss:1.8074
# epoch:884  d_loss:0.5351  g_loss:2.0394
# epoch:885  d_loss:0.5093  g_loss:1.9404
# epoch:886  d_loss:0.3709  g_loss:2.1021
# epoch:887  d_loss:0.5766  g_loss:2.1234
# epoch:888  d_loss:0.4365  g_loss:2.0250
# epoch:889  d_loss:0.3740  g_loss:1.6695
# epoch:890  d_loss:0.4171  g_loss:1.6823
# epoch:891  d_loss:0.3791  g_loss:1.8780
# epoch:892  d_loss:0.2641  g_loss:2.0478
# epoch:893  d_loss:0.3419  g_loss:2.0882
# epoch:894  d_loss:0.3121  g_loss:1.8125
# epoch:895  d_loss:0.3163  g_loss:2.5355
# epoch:896  d_loss:0.4571  g_loss:2.4170
# epoch:897  d_loss:0.4819  g_loss:1.5794
# epoch:898  d_loss:0.4050  g_loss:1.6872
# epoch:899  d_loss:0.4139  g_loss:1.9029
# epoch:900  d_loss:0.2891  g_loss:2.3317
# epoch:901  d_loss:0.3943  g_loss:2.6622
# epoch:902  d_loss:0.3023  g_loss:2.9894
# epoch:903  d_loss:0.4630  g_loss:2.4367
# epoch:904  d_loss:0.2275  g_loss:2.4377
# epoch:905  d_loss:0.2562  g_loss:2.4952
# epoch:906  d_loss:0.2982  g_loss:2.5575
# epoch:907  d_loss:0.4015  g_loss:2.6483
# epoch:908  d_loss:0.2949  g_loss:2.0159
# epoch:909  d_loss:0.3321  g_loss:2.2985
# epoch:910  d_loss:0.3592  g_loss:2.2896
# epoch:911  d_loss:0.5503  g_loss:2.6627
# epoch:912  d_loss:0.5160  g_loss:2.6283
# epoch:913  d_loss:0.5522  g_loss:2.1816
# epoch:914  d_loss:0.4540  g_loss:1.9127
# epoch:915  d_loss:0.5398  g_loss:2.4641
# epoch:916  d_loss:0.4873  g_loss:2.2147
# epoch:917  d_loss:0.4555  g_loss:2.3397
# epoch:918  d_loss:0.5452  g_loss:1.8420
# epoch:919  d_loss:0.6933  g_loss:1.7685
# epoch:920  d_loss:0.4382  g_loss:2.2125
# epoch:921  d_loss:0.5682  g_loss:1.9201
# epoch:922  d_loss:0.5487  g_loss:1.6899
# epoch:923  d_loss:0.4879  g_loss:2.2900
# epoch:924  d_loss:0.3849  g_loss:2.1501
# epoch:925  d_loss:0.5631  g_loss:1.7722
# epoch:926  d_loss:0.4177  g_loss:2.0190
# epoch:927  d_loss:0.4071  g_loss:2.4334
# epoch:928  d_loss:0.5208  g_loss:2.2941
# epoch:929  d_loss:0.4982  g_loss:1.7149
# epoch:930  d_loss:0.3843  g_loss:1.9518
# epoch:931  d_loss:0.3290  g_loss:2.2541
# epoch:932  d_loss:0.2382  g_loss:2.1879
# epoch:933  d_loss:0.2678  g_loss:2.1358
# epoch:934  d_loss:0.2720  g_loss:2.5710
# epoch:935  d_loss:0.2111  g_loss:2.5568
# epoch:936  d_loss:0.2287  g_loss:2.4759
# epoch:937  d_loss:0.2117  g_loss:2.9151
# epoch:938  d_loss:0.2665  g_loss:2.7344
# epoch:939  d_loss:0.2482  g_loss:2.1201
# epoch:940  d_loss:0.2434  g_loss:2.9584
# epoch:941  d_loss:0.2457  g_loss:2.3805
# epoch:942  d_loss:0.2350  g_loss:2.5909
# epoch:943  d_loss:0.2265  g_loss:2.5708
# epoch:944  d_loss:0.2932  g_loss:2.6041
# epoch:945  d_loss:0.2793  g_loss:3.3867
# epoch:946  d_loss:0.2246  g_loss:3.4279
# epoch:947  d_loss:0.2881  g_loss:2.9303
# epoch:948  d_loss:0.2745  g_loss:2.7551
# epoch:949  d_loss:0.1773  g_loss:3.1211
# epoch:950  d_loss:0.3352  g_loss:2.6024
# epoch:951  d_loss:0.2562  g_loss:2.4903
# epoch:952  d_loss:0.2626  g_loss:2.8296
# epoch:953  d_loss:0.2561  g_loss:2.3319
# epoch:954  d_loss:0.3277  g_loss:2.2241
# epoch:955  d_loss:0.4224  g_loss:1.9914
# epoch:956  d_loss:0.3720  g_loss:2.5649
# epoch:957  d_loss:0.4122  g_loss:2.2740
# epoch:958  d_loss:0.3910  g_loss:1.6811
# epoch:959  d_loss:0.4121  g_loss:1.8912
# epoch:960  d_loss:0.4528  g_loss:1.8911
# epoch:961  d_loss:0.2943  g_loss:2.3496
# epoch:962  d_loss:0.3989  g_loss:2.9081
# epoch:963  d_loss:0.4503  g_loss:1.7828
# epoch:964  d_loss:0.4582  g_loss:1.2442
# epoch:965  d_loss:0.3387  g_loss:1.9625
# epoch:966  d_loss:0.4202  g_loss:2.0237
# epoch:967  d_loss:0.4312  g_loss:2.4015
# epoch:968  d_loss:0.4635  g_loss:2.0101
# epoch:969  d_loss:0.5630  g_loss:1.7201
# epoch:970  d_loss:0.4886  g_loss:1.8666
# epoch:971  d_loss:0.5963  g_loss:1.6222
# epoch:972  d_loss:0.4803  g_loss:2.2162
# epoch:973  d_loss:0.3730  g_loss:2.7646
# epoch:974  d_loss:0.3917  g_loss:2.8467
# epoch:975  d_loss:0.3449  g_loss:2.4250
# epoch:976  d_loss:0.3310  g_loss:2.1561
# epoch:977  d_loss:0.2723  g_loss:2.1334
# epoch:978  d_loss:0.3137  g_loss:1.8600
# epoch:979  d_loss:0.3034  g_loss:3.1439
# epoch:980  d_loss:0.1422  g_loss:4.0588
# epoch:981  d_loss:0.2238  g_loss:3.3559
# epoch:982  d_loss:0.3095  g_loss:3.2853
# epoch:983  d_loss:0.2705  g_loss:2.2394
# epoch:984  d_loss:0.3306  g_loss:2.3200
# epoch:985  d_loss:0.3379  g_loss:2.2789
# epoch:986  d_loss:0.3545  g_loss:2.6901
# epoch:987  d_loss:0.3106  g_loss:2.5876
# epoch:988  d_loss:0.3955  g_loss:2.7451
# epoch:989  d_loss:0.3840  g_loss:3.0183
# epoch:990  d_loss:0.4204  g_loss:2.2876
# epoch:991  d_loss:0.4917  g_loss:2.0272
# epoch:992  d_loss:0.3640  g_loss:1.6585
# epoch:993  d_loss:0.3399  g_loss:2.3862
# epoch:994  d_loss:0.3093  g_loss:2.6767
# epoch:995  d_loss:0.4495  g_loss:2.4519
# epoch:996  d_loss:0.3011  g_loss:2.6762
# epoch:997  d_loss:0.3852  g_loss:2.3336
# epoch:998  d_loss:0.3151  g_loss:2.1722
# epoch:999  d_loss:0.3650  g_loss:2.0527
# epoch:1000  d_loss:0.3312  g_loss:2.1439
# epoch:1001  d_loss:0.4320  g_loss:1.9900
# epoch:1002  d_loss:0.3437  g_loss:2.0487
# epoch:1003  d_loss:0.3232  g_loss:2.6379
# epoch:1004  d_loss:0.5209  g_loss:2.4106
# epoch:1005  d_loss:0.3909  g_loss:1.9518
# epoch:1006  d_loss:0.3331  g_loss:2.2601
# epoch:1007  d_loss:0.4338  g_loss:2.1455
# epoch:1008  d_loss:0.3065  g_loss:2.2068
# epoch:1009  d_loss:0.4076  g_loss:2.3607
# epoch:1010  d_loss:0.2355  g_loss:2.8133
# epoch:1011  d_loss:0.5648  g_loss:2.1796
# epoch:1012  d_loss:0.3572  g_loss:2.3766
# epoch:1013  d_loss:0.2955  g_loss:1.8721
# epoch:1014  d_loss:0.3374  g_loss:2.5723
# epoch:1015  d_loss:0.3563  g_loss:1.9610
# epoch:1016  d_loss:0.3432  g_loss:2.3367
# epoch:1017  d_loss:0.5277  g_loss:1.8512
# epoch:1018  d_loss:0.3944  g_loss:1.7582
# epoch:1019  d_loss:0.3990  g_loss:1.9730
# epoch:1020  d_loss:0.5714  g_loss:2.1630
# epoch:1021  d_loss:0.4514  g_loss:2.2117
# epoch:1022  d_loss:0.5076  g_loss:2.1412
# epoch:1023  d_loss:0.5215  g_loss:2.0583
# epoch:1024  d_loss:0.4893  g_loss:1.7203
# epoch:1025  d_loss:0.3787  g_loss:2.0393
# epoch:1026  d_loss:0.3860  g_loss:2.0881
# epoch:1027  d_loss:0.4626  g_loss:1.6755
# epoch:1028  d_loss:0.4809  g_loss:1.7708
# epoch:1029  d_loss:0.3043  g_loss:1.9608
# epoch:1030  d_loss:0.2827  g_loss:2.2363
# epoch:1031  d_loss:0.2465  g_loss:2.5856
# epoch:1032  d_loss:0.2457  g_loss:2.0839
# epoch:1033  d_loss:0.5823  g_loss:1.7484
# epoch:1034  d_loss:0.3031  g_loss:2.3275
# epoch:1035  d_loss:0.2582  g_loss:2.9593
# epoch:1036  d_loss:0.2331  g_loss:3.0868
# epoch:1037  d_loss:0.2306  g_loss:3.0619
# epoch:1038  d_loss:0.2230  g_loss:2.9453
# epoch:1039  d_loss:0.2171  g_loss:2.5056
# epoch:1040  d_loss:0.2409  g_loss:3.1847
# epoch:1041  d_loss:0.1809  g_loss:3.2756
# epoch:1042  d_loss:0.2400  g_loss:3.0224
# epoch:1043  d_loss:0.2574  g_loss:2.6195
# epoch:1044  d_loss:0.2438  g_loss:2.5322
# epoch:1045  d_loss:0.2985  g_loss:2.3951
# epoch:1046  d_loss:0.1873  g_loss:2.9088
# epoch:1047  d_loss:0.2477  g_loss:2.6370
# epoch:1048  d_loss:0.3935  g_loss:2.2805
# epoch:1049  d_loss:0.3158  g_loss:2.5849
# epoch:1050  d_loss:0.3222  g_loss:2.2916
# epoch:1051  d_loss:0.2444  g_loss:3.0551
# epoch:1052  d_loss:0.3353  g_loss:3.0756
# epoch:1053  d_loss:0.4923  g_loss:2.5778
# epoch:1054  d_loss:0.5555  g_loss:1.7496
# epoch:1055  d_loss:0.5155  g_loss:1.8614
# epoch:1056  d_loss:0.4298  g_loss:2.0719
# epoch:1057  d_loss:0.3491  g_loss:2.1135
# epoch:1058  d_loss:0.6002  g_loss:1.9068
# epoch:1059  d_loss:0.4278  g_loss:2.2543
# epoch:1060  d_loss:0.4578  g_loss:2.1123
# epoch:1061  d_loss:0.8218  g_loss:1.7283
# epoch:1062  d_loss:0.4743  g_loss:1.9990
# epoch:1063  d_loss:0.7460  g_loss:1.9683
# epoch:1064  d_loss:0.5069  g_loss:1.8897
# epoch:1065  d_loss:0.5635  g_loss:1.3546
# epoch:1066  d_loss:0.5190  g_loss:1.3838
# epoch:1067  d_loss:0.4246  g_loss:2.5327
# epoch:1068  d_loss:0.5022  g_loss:2.1988
# epoch:1069  d_loss:0.4383  g_loss:2.1266
# epoch:1070  d_loss:0.2753  g_loss:2.1613
# epoch:1071  d_loss:0.3188  g_loss:2.5177
# epoch:1072  d_loss:0.1883  g_loss:2.5398
# epoch:1073  d_loss:0.2670  g_loss:2.4935
# epoch:1074  d_loss:0.2579  g_loss:2.8169
# epoch:1075  d_loss:0.2091  g_loss:2.7520
# epoch:1076  d_loss:0.1594  g_loss:2.7664
# epoch:1077  d_loss:0.1685  g_loss:2.3619
# epoch:1078  d_loss:0.2705  g_loss:2.3301
# epoch:1079  d_loss:0.1793  g_loss:3.1648
# epoch:1080  d_loss:0.1383  g_loss:3.2336
# epoch:1081  d_loss:0.2633  g_loss:2.5707
# epoch:1082  d_loss:0.2218  g_loss:3.0933
# epoch:1083  d_loss:0.2353  g_loss:3.1348
# epoch:1084  d_loss:0.2178  g_loss:3.0183
# epoch:1085  d_loss:0.2153  g_loss:2.6436
# epoch:1086  d_loss:0.1703  g_loss:2.6181
# epoch:1087  d_loss:0.1905  g_loss:2.2492
# epoch:1088  d_loss:0.3145  g_loss:2.5582
# epoch:1089  d_loss:0.3360  g_loss:2.7161
# epoch:1090  d_loss:0.3234  g_loss:2.9522
# epoch:1091  d_loss:0.4356  g_loss:2.9251
# epoch:1092  d_loss:0.3560  g_loss:3.2268
# epoch:1093  d_loss:0.4285  g_loss:2.2117
# epoch:1094  d_loss:0.3967  g_loss:2.0254
# epoch:1095  d_loss:0.4348  g_loss:1.9248
# epoch:1096  d_loss:0.5085  g_loss:1.7695
# epoch:1097  d_loss:0.2928  g_loss:1.8532
# epoch:1098  d_loss:0.5421  g_loss:2.6681
# epoch:1099  d_loss:0.5837  g_loss:2.2857
# epoch:1100  d_loss:0.3015  g_loss:2.5266
# epoch:1101  d_loss:0.6681  g_loss:2.0345
# epoch:1102  d_loss:0.4769  g_loss:1.6438
# epoch:1103  d_loss:0.3383  g_loss:1.7759
# epoch:1104  d_loss:0.4825  g_loss:2.2370
# epoch:1105  d_loss:0.3797  g_loss:2.0820
# epoch:1106  d_loss:0.3237  g_loss:2.3022
# epoch:1107  d_loss:0.2990  g_loss:2.1507
# epoch:1108  d_loss:0.3257  g_loss:2.4634
# epoch:1109  d_loss:0.3088  g_loss:1.8886
# epoch:1110  d_loss:0.2314  g_loss:2.3990
# epoch:1111  d_loss:0.1955  g_loss:2.8218
# epoch:1112  d_loss:0.2808  g_loss:2.9277
# epoch:1113  d_loss:0.4704  g_loss:2.7212
# epoch:1114  d_loss:0.2051  g_loss:2.8925
# epoch:1115  d_loss:0.2669  g_loss:2.6158
# epoch:1116  d_loss:0.1680  g_loss:2.6934
# epoch:1117  d_loss:0.3234  g_loss:2.3487
# epoch:1118  d_loss:0.1914  g_loss:2.5924
# epoch:1119  d_loss:0.2699  g_loss:2.3844
# epoch:1120  d_loss:0.2066  g_loss:2.2274
# epoch:1121  d_loss:0.2891  g_loss:2.1695
# epoch:1122  d_loss:0.3846  g_loss:2.0751
# epoch:1123  d_loss:0.3279  g_loss:2.2542
# epoch:1124  d_loss:0.4533  g_loss:2.7068
# epoch:1125  d_loss:0.3601  g_loss:2.3182
# epoch:1126  d_loss:0.4107  g_loss:2.2123
# epoch:1127  d_loss:0.2769  g_loss:2.1757
# epoch:1128  d_loss:0.3172  g_loss:1.8232
# epoch:1129  d_loss:0.3991  g_loss:1.7777
# epoch:1130  d_loss:0.3821  g_loss:2.0736
# epoch:1131  d_loss:0.3401  g_loss:2.3612
# epoch:1132  d_loss:0.3880  g_loss:2.1333
# epoch:1133  d_loss:0.4120  g_loss:1.8665
# epoch:1134  d_loss:0.7249  g_loss:1.6392
# epoch:1135  d_loss:0.5030  g_loss:1.4028
# epoch:1136  d_loss:0.4124  g_loss:1.7205
# epoch:1137  d_loss:0.3420  g_loss:1.9740
# epoch:1138  d_loss:0.5141  g_loss:2.5971
# epoch:1139  d_loss:0.4372  g_loss:2.1730
# epoch:1140  d_loss:0.4081  g_loss:1.8860
# epoch:1141  d_loss:0.4377  g_loss:2.1319
# epoch:1142  d_loss:0.3915  g_loss:2.0054
# epoch:1143  d_loss:0.3834  g_loss:2.0020
# epoch:1144  d_loss:0.4722  g_loss:2.0363
# epoch:1145  d_loss:0.4903  g_loss:1.6932
# epoch:1146  d_loss:0.5147  g_loss:1.7900
# epoch:1147  d_loss:0.3880  g_loss:1.8847
# epoch:1148  d_loss:0.4537  g_loss:1.7863
# epoch:1149  d_loss:0.3530  g_loss:2.1214
# epoch:1150  d_loss:0.3672  g_loss:2.3416
# epoch:1151  d_loss:0.3727  g_loss:2.2214
# epoch:1152  d_loss:0.4137  g_loss:2.3107
# epoch:1153  d_loss:0.3583  g_loss:1.7726
# epoch:1154  d_loss:0.3050  g_loss:2.4159
# epoch:1155  d_loss:0.3550  g_loss:2.6603
# epoch:1156  d_loss:0.3746  g_loss:2.4906
# epoch:1157  d_loss:0.3609  g_loss:2.5741
# epoch:1158  d_loss:0.4229  g_loss:2.0466
# epoch:1159  d_loss:0.3696  g_loss:2.3989
# epoch:1160  d_loss:0.2803  g_loss:2.6547
# epoch:1161  d_loss:0.3121  g_loss:2.7032
# epoch:1162  d_loss:0.3925  g_loss:3.0714
# epoch:1163  d_loss:0.2794  g_loss:2.8324
# epoch:1164  d_loss:0.2837  g_loss:2.5488
# epoch:1165  d_loss:0.3430  g_loss:2.2050
# epoch:1166  d_loss:0.3040  g_loss:2.5389
# epoch:1167  d_loss:0.4374  g_loss:2.1237
# epoch:1168  d_loss:0.2966  g_loss:2.2544
# epoch:1169  d_loss:0.2807  g_loss:2.6108
# epoch:1170  d_loss:0.2221  g_loss:2.3937
# epoch:1171  d_loss:0.3844  g_loss:2.7930
# epoch:1172  d_loss:0.3627  g_loss:2.5820
# epoch:1173  d_loss:0.4168  g_loss:2.2387
# epoch:1174  d_loss:0.4591  g_loss:2.4115
# epoch:1175  d_loss:0.3819  g_loss:2.4731
# epoch:1176  d_loss:0.4284  g_loss:2.1486
# epoch:1177  d_loss:0.5489  g_loss:1.9240
# epoch:1178  d_loss:0.3561  g_loss:2.2967
# epoch:1179  d_loss:0.4943  g_loss:1.7717
# epoch:1180  d_loss:0.2717  g_loss:2.2739
# epoch:1181  d_loss:0.3431  g_loss:2.2623
# epoch:1182  d_loss:0.3005  g_loss:2.7928
# epoch:1183  d_loss:0.3280  g_loss:2.6539
# epoch:1184  d_loss:0.2882  g_loss:1.8440
# epoch:1185  d_loss:0.3495  g_loss:2.2070
# epoch:1186  d_loss:0.4142  g_loss:1.9186
# epoch:1187  d_loss:0.2767  g_loss:2.2041
# epoch:1188  d_loss:0.2823  g_loss:2.0834
# epoch:1189  d_loss:0.2604  g_loss:2.2414
# epoch:1190  d_loss:0.2822  g_loss:2.4030
# epoch:1191  d_loss:0.2285  g_loss:1.8957
# epoch:1192  d_loss:0.2929  g_loss:2.4149
# epoch:1193  d_loss:0.4094  g_loss:3.0618
# epoch:1194  d_loss:0.2441  g_loss:3.3591
# epoch:1195  d_loss:0.4274  g_loss:2.8388
# epoch:1196  d_loss:0.4949  g_loss:2.4211
# ...
# epoch:3620  d_loss:0.5149  g_loss:1.6112
# epoch:3621  d_loss:0.5480  g_loss:1.4185
# epoch:3622  d_loss:0.3365  g_loss:2.5309
# epoch:3623  d_loss:0.5476  g_loss:2.0770
# epoch:3624  d_loss:0.5181  g_loss:1.6437
# epoch:3625  d_loss:0.5048  g_loss:1.4665
# epoch:3626  d_loss:0.4298  g_loss:1.3105
# epoch:3627  d_loss:0.4914  g_loss:1.4225
# epoch:3628  d_loss:0.4925  g_loss:1.5145
# epoch:3629  d_loss:0.5224  g_loss:1.7326
# epoch:3630  d_loss:0.5125  g_loss:1.8843
# epoch:3631  d_loss:0.4460  g_loss:2.2468
# epoch:3632  d_loss:0.5043  g_loss:1.9250
# epoch:3633  d_loss:0.5817  g_loss:1.6680
# epoch:3634  d_loss:0.6001  g_loss:1.5005
# epoch:3635  d_loss:0.3633  g_loss:1.6231
# epoch:3636  d_loss:0.4031  g_loss:1.5391
# epoch:3637  d_loss:0.3750  g_loss:2.0088
# epoch:3638  d_loss:0.4643  g_loss:2.4067
# epoch:3639  d_loss:0.4994  g_loss:2.4662
# epoch:3640  d_loss:0.5841  g_loss:1.6692
# epoch:3641  d_loss:0.4916  g_loss:1.5111
# epoch:3642  d_loss:0.4929  g_loss:1.4859
# epoch:3643  d_loss:0.4400  g_loss:1.3638
# epoch:3644  d_loss:0.4227  g_loss:1.8900
# epoch:3645  d_loss:0.5166  g_loss:2.3842
# epoch:3646  d_loss:0.3949  g_loss:2.3004
# epoch:3647  d_loss:0.6057  g_loss:1.9838
# epoch:3648  d_loss:0.6543  g_loss:1.5799
# epoch:3649  d_loss:0.5093  g_loss:1.5248
# epoch:3650  d_loss:0.4551  g_loss:1.1849
# epoch:3651  d_loss:0.4805  g_loss:1.9381
# epoch:3652  d_loss:0.4171  g_loss:1.9974
# epoch:3653  d_loss:0.4231  g_loss:1.9720
# epoch:3654  d_loss:0.4413  g_loss:1.6231
# epoch:3655  d_loss:0.4479  g_loss:1.7125
# epoch:3656  d_loss:0.4430  g_loss:2.0729
# epoch:3657  d_loss:0.4667  g_loss:1.9002
# epoch:3658  d_loss:0.4870  g_loss:1.9840
# epoch:3659  d_loss:0.4512  g_loss:1.9048
# epoch:3660  d_loss:0.5138  g_loss:2.3299
# epoch:3661  d_loss:0.4819  g_loss:2.5912
# epoch:3662  d_loss:0.4842  g_loss:2.4546
# epoch:3663  d_loss:0.4521  g_loss:2.0737
# epoch:3664  d_loss:0.4018  g_loss:2.0116
# epoch:3665  d_loss:0.3720  g_loss:1.6225
# epoch:3666  d_loss:0.4922  g_loss:1.7544
# epoch:3667  d_loss:0.4960  g_loss:1.9100
# epoch:3668  d_loss:0.4910  g_loss:2.0298
# epoch:3669  d_loss:0.5142  g_loss:1.6270
# epoch:3670  d_loss:0.5564  g_loss:1.5542
# epoch:3671  d_loss:0.4108  g_loss:1.7427
# epoch:3672  d_loss:0.4011  g_loss:1.9481
# epoch:3673  d_loss:0.4362  g_loss:2.2298
# epoch:3674  d_loss:0.4114  g_loss:2.3358
# epoch:3675  d_loss:0.4865  g_loss:2.0620
# epoch:3676  d_loss:0.3893  g_loss:1.7153
# epoch:3677  d_loss:0.3522  g_loss:2.1043
# epoch:3678  d_loss:0.4358  g_loss:1.8737
# epoch:3679  d_loss:0.4041  g_loss:1.9524
# epoch:3680  d_loss:0.4259  g_loss:1.5972
# epoch:3681  d_loss:0.4166  g_loss:1.7059
# epoch:3682  d_loss:0.5154  g_loss:1.9603
# epoch:3683  d_loss:0.5703  g_loss:2.0705
# epoch:3684  d_loss:0.3475  g_loss:1.7737
# epoch:3685  d_loss:0.4258  g_loss:1.9912
# epoch:3686  d_loss:0.6078  g_loss:1.6042
# epoch:3687  d_loss:0.4870  g_loss:1.5655
# epoch:3688  d_loss:0.4622  g_loss:1.2193
# epoch:3689  d_loss:0.6609  g_loss:1.5511
# epoch:3690  d_loss:0.6215  g_loss:1.5471
# epoch:3691  d_loss:0.6022  g_loss:1.9179
# epoch:3692  d_loss:0.4569  g_loss:1.5785
# epoch:3693  d_loss:0.5361  g_loss:1.5802
# epoch:3694  d_loss:0.4541  g_loss:1.5348
# epoch:3695  d_loss:0.5549  g_loss:1.2417
# epoch:3696  d_loss:0.5881  g_loss:1.4010
# epoch:3697  d_loss:0.5685  g_loss:1.3515
# epoch:3698  d_loss:0.4925  g_loss:1.5696
# epoch:3699  d_loss:0.4433  g_loss:1.9013
# epoch:3700  d_loss:0.4235  g_loss:1.9505
# epoch:3701  d_loss:0.6140  g_loss:1.7799
# epoch:3702  d_loss:0.5683  g_loss:1.9686
# epoch:3703  d_loss:0.5225  g_loss:1.5821
# epoch:3704  d_loss:0.4254  g_loss:1.6264
# epoch:3705  d_loss:0.5138  g_loss:1.5277
# epoch:3706  d_loss:0.3375  g_loss:1.8091
# epoch:3707  d_loss:0.5753  g_loss:1.7492
# epoch:3708  d_loss:0.5102  g_loss:1.7414
# epoch:3709  d_loss:0.4010  g_loss:1.8599
# epoch:3710  d_loss:0.4014  g_loss:2.3108
# epoch:3711  d_loss:0.4845  g_loss:1.6038
# epoch:3712  d_loss:0.4048  g_loss:1.7954
# epoch:3713  d_loss:0.3127  g_loss:2.5711
# epoch:3714  d_loss:0.5734  g_loss:1.9012
# epoch:3715  d_loss:0.4289  g_loss:1.7916
# epoch:3716  d_loss:0.3631  g_loss:2.4206
# epoch:3717  d_loss:0.5638  g_loss:1.5366
# epoch:3718  d_loss:0.6041  g_loss:1.5897
# epoch:3719  d_loss:0.3051  g_loss:1.8212
# epoch:3720  d_loss:0.3602  g_loss:2.0441
# epoch:3721  d_loss:0.4140  g_loss:2.2907
# epoch:3722  d_loss:0.6668  g_loss:2.0337
# epoch:3723  d_loss:0.4652  g_loss:2.3091
# epoch:3724  d_loss:0.3351  g_loss:2.3769
# epoch:3725  d_loss:0.4685  g_loss:2.0586
# epoch:3726  d_loss:0.3920  g_loss:2.0050
# epoch:3727  d_loss:0.6959  g_loss:1.1759
# epoch:3728  d_loss:0.5997  g_loss:1.3776
# epoch:3729  d_loss:0.5768  g_loss:1.5580
# epoch:3730  d_loss:0.4873  g_loss:2.0329
# epoch:3731  d_loss:0.4778  g_loss:2.1562
# epoch:3732  d_loss:0.5067  g_loss:2.4801
# epoch:3733  d_loss:0.6194  g_loss:2.1604
# epoch:3734  d_loss:0.8320  g_loss:1.6606
# epoch:3735  d_loss:0.6274  g_loss:1.7100
# epoch:3736  d_loss:0.5000  g_loss:1.5435
# epoch:3737  d_loss:0.4918  g_loss:1.6881
# epoch:3738  d_loss:0.4707  g_loss:1.7217
# epoch:3739  d_loss:0.4315  g_loss:1.6183
# epoch:3740  d_loss:0.5989  g_loss:1.6860
# epoch:3741  d_loss:0.6031  g_loss:1.6535
# epoch:3742  d_loss:0.4360  g_loss:1.8427
# epoch:3743  d_loss:0.4062  g_loss:1.7508
# epoch:3744  d_loss:0.5434  g_loss:1.5297
# epoch:3745  d_loss:0.4389  g_loss:1.8686
# epoch:3746  d_loss:0.4123  g_loss:1.7524
# epoch:3747  d_loss:0.4928  g_loss:1.9200
# epoch:3748  d_loss:0.4377  g_loss:1.9413
# epoch:3749  d_loss:0.4913  g_loss:1.7152
# epoch:3750  d_loss:0.5198  g_loss:1.8483
# epoch:3751  d_loss:0.4391  g_loss:1.8395
# epoch:3752  d_loss:0.4528  g_loss:2.1952
# epoch:3753  d_loss:0.5192  g_loss:1.7590
# epoch:3754  d_loss:0.4529  g_loss:1.7837
# epoch:3755  d_loss:0.3906  g_loss:2.0622
# epoch:3756  d_loss:0.3204  g_loss:1.8986
# epoch:3757  d_loss:0.3393  g_loss:2.4625
# epoch:3758  d_loss:0.3580  g_loss:2.6380
# epoch:3759  d_loss:0.5129  g_loss:2.1996
# epoch:3760  d_loss:0.5490  g_loss:2.2235
# epoch:3761  d_loss:0.4996  g_loss:1.9229
# epoch:3762  d_loss:0.4661  g_loss:1.8881
# epoch:3763  d_loss:0.5082  g_loss:1.7437
# epoch:3764  d_loss:0.3781  g_loss:2.1217
# epoch:3765  d_loss:0.4560  g_loss:1.8665
# epoch:3766  d_loss:0.7654  g_loss:1.7252
# epoch:3767  d_loss:0.5294  g_loss:1.1717
# epoch:3768  d_loss:0.4391  g_loss:1.4921
# epoch:3769  d_loss:0.4485  g_loss:1.6024
# epoch:3770  d_loss:0.4397  g_loss:1.6004
# epoch:3771  d_loss:0.4934  g_loss:1.9664
# epoch:3772  d_loss:0.6764  g_loss:1.2373
# epoch:3773  d_loss:0.7102  g_loss:1.5170
# epoch:3774  d_loss:0.5542  g_loss:1.3776
# epoch:3775  d_loss:0.4755  g_loss:1.7581
# epoch:3776  d_loss:0.5168  g_loss:1.4386
# epoch:3777  d_loss:0.5039  g_loss:1.4641
# epoch:3778  d_loss:0.4873  g_loss:1.8231
# epoch:3779  d_loss:0.6243  g_loss:1.8009
# epoch:3780  d_loss:0.3643  g_loss:2.0562
# epoch:3781  d_loss:0.6394  g_loss:1.8078
# epoch:3782  d_loss:0.4242  g_loss:1.4134
# epoch:3783  d_loss:0.6883  g_loss:1.5571
# epoch:3784  d_loss:0.5583  g_loss:1.3713
# epoch:3785  d_loss:0.5090  g_loss:1.5551
# epoch:3786  d_loss:0.4427  g_loss:1.7596
# epoch:3787  d_loss:0.4289  g_loss:1.7096
# epoch:3788  d_loss:0.5020  g_loss:1.8224
# epoch:3789  d_loss:0.5426  g_loss:1.5838
# epoch:3790  d_loss:0.5173  g_loss:1.6124
# epoch:3791  d_loss:0.4468  g_loss:1.2808
# epoch:3792  d_loss:0.4177  g_loss:1.4116
# epoch:3793  d_loss:0.4294  g_loss:1.2846
# epoch:3794  d_loss:0.6506  g_loss:1.3107
# epoch:3795  d_loss:0.3971  g_loss:1.8946
# epoch:3796  d_loss:0.3719  g_loss:2.0719
# epoch:3797  d_loss:0.3609  g_loss:1.5997
# epoch:3798  d_loss:0.3690  g_loss:2.0360
# epoch:3799  d_loss:0.4473  g_loss:1.8883
# epoch:3800  d_loss:0.4079  g_loss:2.5151
# epoch:3801  d_loss:0.4479  g_loss:1.7485
# epoch:3802  d_loss:0.5301  g_loss:1.2781
# epoch:3803  d_loss:0.4974  g_loss:1.3621
# epoch:3804  d_loss:0.4790  g_loss:1.6873
# epoch:3805  d_loss:0.3491  g_loss:2.3500
# epoch:3806  d_loss:0.5453  g_loss:1.9082
# epoch:3807  d_loss:0.3924  g_loss:2.3592
# epoch:3808  d_loss:0.4745  g_loss:1.9198
# epoch:3809  d_loss:0.5694  g_loss:1.5233
# epoch:3810  d_loss:0.5291  g_loss:1.4101
# epoch:3811  d_loss:0.3845  g_loss:1.4549
# epoch:3812  d_loss:0.5122  g_loss:1.3974
# epoch:3813  d_loss:0.5083  g_loss:1.9805
# epoch:3814  d_loss:0.4228  g_loss:2.2339
# epoch:3815  d_loss:0.5670  g_loss:1.9299
# epoch:3816  d_loss:0.6614  g_loss:1.4295
# epoch:3817  d_loss:0.5158  g_loss:1.4861
# epoch:3818  d_loss:0.5561  g_loss:1.2857
# epoch:3819  d_loss:0.4949  g_loss:1.6220
# epoch:3820  d_loss:0.5960  g_loss:2.0694
# epoch:3821  d_loss:0.5723  g_loss:1.7373
# epoch:3822  d_loss:0.5069  g_loss:1.9883
# epoch:3823  d_loss:0.6245  g_loss:1.7058
# epoch:3824  d_loss:0.5890  g_loss:1.1991
# epoch:3825  d_loss:0.6213  g_loss:1.3120
# epoch:3826  d_loss:0.3754  g_loss:1.7207
# epoch:3827  d_loss:0.5608  g_loss:1.4738
# epoch:3828  d_loss:0.4225  g_loss:1.9274
# epoch:3829  d_loss:0.4027  g_loss:1.5513
# epoch:3830  d_loss:0.4955  g_loss:1.7341
# epoch:3831  d_loss:0.4797  g_loss:1.7403
# epoch:3832  d_loss:0.6070  g_loss:1.6560
# epoch:3833  d_loss:0.3871  g_loss:1.5547
# epoch:3834  d_loss:0.3717  g_loss:1.7075
# epoch:3835  d_loss:0.4877  g_loss:1.5693
# epoch:3836  d_loss:0.3407  g_loss:1.7206
# epoch:3837  d_loss:0.4523  g_loss:2.0655
# epoch:3838  d_loss:0.3685  g_loss:1.7513
# epoch:3839  d_loss:0.3841  g_loss:1.7094
# epoch:3840  d_loss:0.3894  g_loss:1.6794
# epoch:3841  d_loss:0.5151  g_loss:1.5134
# epoch:3842  d_loss:0.3548  g_loss:1.8667
# epoch:3843  d_loss:0.3879  g_loss:1.7628
# epoch:3844  d_loss:0.5085  g_loss:1.7200
# epoch:3845  d_loss:0.5023  g_loss:1.7111
# epoch:3846  d_loss:0.4338  g_loss:1.3772
# epoch:3847  d_loss:0.3964  g_loss:2.1961
# epoch:3848  d_loss:0.4353  g_loss:1.6549
# epoch:3849  d_loss:0.6081  g_loss:1.6631
# epoch:3850  d_loss:0.5488  g_loss:1.5230
# epoch:3851  d_loss:0.3997  g_loss:1.5739
# epoch:3852  d_loss:0.4497  g_loss:1.7229
# epoch:3853  d_loss:0.5103  g_loss:1.3495
# epoch:3854  d_loss:0.4779  g_loss:1.3616
# epoch:3855  d_loss:0.4819  g_loss:1.4408
# epoch:3856  d_loss:0.6000  g_loss:1.4171
# epoch:3857  d_loss:0.5673  g_loss:1.7526
# epoch:3858  d_loss:0.5122  g_loss:1.5605
# epoch:3859  d_loss:0.6020  g_loss:1.9325
# epoch:3860  d_loss:0.6189  g_loss:1.7825
# epoch:3861  d_loss:0.5719  g_loss:1.6320
# epoch:3862  d_loss:0.6711  g_loss:1.3666
# epoch:3863  d_loss:0.6985  g_loss:1.1141
# epoch:3864  d_loss:0.5340  g_loss:1.2829
# epoch:3865  d_loss:0.4886  g_loss:1.4331
# epoch:3866  d_loss:0.5198  g_loss:1.8926
# epoch:3867  d_loss:0.5053  g_loss:1.8795
# epoch:3868  d_loss:0.4522  g_loss:1.8425
# epoch:3869  d_loss:0.6202  g_loss:1.6682
# epoch:3870  d_loss:0.5742  g_loss:1.3757
# epoch:3871  d_loss:0.5546  g_loss:1.2117
# epoch:3872  d_loss:0.4449  g_loss:1.4385
# epoch:3873  d_loss:0.5198  g_loss:1.7175
# epoch:3874  d_loss:0.5079  g_loss:1.5444
# epoch:3875  d_loss:0.5294  g_loss:1.6041
# epoch:3876  d_loss:0.4563  g_loss:2.0949
# epoch:3877  d_loss:0.4117  g_loss:2.1927
# epoch:3878  d_loss:0.4294  g_loss:1.7994
# epoch:3879  d_loss:0.4728  g_loss:1.5358
# epoch:3880  d_loss:0.4123  g_loss:1.6440
# epoch:3881  d_loss:0.4020  g_loss:1.7471
# epoch:3882  d_loss:0.4904  g_loss:1.4901
# epoch:3883  d_loss:0.4534  g_loss:1.5923
# epoch:3884  d_loss:0.5309  g_loss:1.5194
# epoch:3885  d_loss:0.3993  g_loss:1.6039
# epoch:3886  d_loss:0.5578  g_loss:2.3566
# epoch:3887  d_loss:0.5307  g_loss:1.8648
# epoch:3888  d_loss:0.4533  g_loss:1.7705
# epoch:3889  d_loss:0.5758  g_loss:1.7501
# epoch:3890  d_loss:0.4335  g_loss:1.7275
# epoch:3891  d_loss:0.4431  g_loss:1.7213
# epoch:3892  d_loss:0.5480  g_loss:1.7984
# epoch:3893  d_loss:0.4045  g_loss:1.5907
# epoch:3894  d_loss:0.3930  g_loss:1.5178
# epoch:3895  d_loss:0.4936  g_loss:1.5008
# epoch:3896  d_loss:0.3872  g_loss:1.5771
# epoch:3897  d_loss:0.5535  g_loss:1.2853
# epoch:3898  d_loss:0.4666  g_loss:1.7839
# epoch:3899  d_loss:0.5342  g_loss:1.8685
# epoch:3900  d_loss:0.5025  g_loss:2.6995
# epoch:3901  d_loss:0.3852  g_loss:1.8589
# epoch:3902  d_loss:0.4958  g_loss:1.9049
# epoch:3903  d_loss:0.4633  g_loss:1.4121
# epoch:3904  d_loss:0.5295  g_loss:1.9216
# epoch:3905  d_loss:0.4931  g_loss:1.6241
# epoch:3906  d_loss:0.4163  g_loss:1.7466
# epoch:3907  d_loss:0.4338  g_loss:2.1629
# epoch:3908  d_loss:0.4094  g_loss:2.2614
# epoch:3909  d_loss:0.4390  g_loss:2.3878
# epoch:3910  d_loss:0.4771  g_loss:1.8804
# epoch:3911  d_loss:0.4741  g_loss:1.5545
# epoch:3912  d_loss:0.5081  g_loss:1.5916
# epoch:3913  d_loss:0.4369  g_loss:1.7390
# epoch:3914  d_loss:0.3980  g_loss:1.5198
# epoch:3915  d_loss:0.4733  g_loss:2.0653
# epoch:3916  d_loss:0.4866  g_loss:1.6327
# epoch:3917  d_loss:0.5225  g_loss:1.7067
# epoch:3918  d_loss:0.4203  g_loss:1.7759
# epoch:3919  d_loss:0.4869  g_loss:1.6511
# epoch:3920  d_loss:0.5497  g_loss:1.4277
# epoch:3921  d_loss:0.4968  g_loss:1.6772
# epoch:3922  d_loss:0.4869  g_loss:2.0001
# epoch:3923  d_loss:0.4526  g_loss:1.7967
# epoch:3924  d_loss:0.4681  g_loss:2.1774
# epoch:3925  d_loss:0.5471  g_loss:1.9069
# epoch:3926  d_loss:0.5700  g_loss:1.1447
# epoch:3927  d_loss:0.4460  g_loss:1.1955
# epoch:3928  d_loss:0.5435  g_loss:1.1527
# epoch:3929  d_loss:0.5260  g_loss:1.6263
# epoch:3930  d_loss:0.5867  g_loss:2.0444
# epoch:3931  d_loss:0.4625  g_loss:1.8618
# epoch:3932  d_loss:0.4305  g_loss:1.5622
# epoch:3933  d_loss:0.4683  g_loss:1.8639
# epoch:3934  d_loss:0.4978  g_loss:1.7278
# epoch:3935  d_loss:0.4919  g_loss:1.4211
# epoch:3936  d_loss:0.4151  g_loss:1.7387
# epoch:3937  d_loss:0.4669  g_loss:2.0846
# epoch:3938  d_loss:0.5340  g_loss:1.7193
# epoch:3939  d_loss:0.4724  g_loss:1.8547
# epoch:3940  d_loss:0.4719  g_loss:1.6113
# epoch:3941  d_loss:0.3738  g_loss:2.2066
# epoch:3942  d_loss:0.4204  g_loss:1.8431
# epoch:3943  d_loss:0.3780  g_loss:1.9154
# epoch:3944  d_loss:0.4347  g_loss:2.0636
# epoch:3945  d_loss:0.4270  g_loss:2.0239
# epoch:3946  d_loss:0.5680  g_loss:1.6317
# epoch:3947  d_loss:0.4923  g_loss:1.8735
# epoch:3948  d_loss:0.3896  g_loss:2.0006
# epoch:3949  d_loss:0.4351  g_loss:1.9336
# epoch:3950  d_loss:0.4309  g_loss:1.7997
# epoch:3951  d_loss:0.5270  g_loss:1.8654
# epoch:3952  d_loss:0.6557  g_loss:1.6832
# epoch:3953  d_loss:0.7192  g_loss:1.8259
# epoch:3954  d_loss:0.5050  g_loss:1.5006
# epoch:3955  d_loss:0.6225  g_loss:1.8115
# epoch:3956  d_loss:0.7046  g_loss:1.4754
# epoch:3957  d_loss:0.6441  g_loss:1.4570
# epoch:3958  d_loss:0.5066  g_loss:1.3106
# epoch:3959  d_loss:0.4445  g_loss:1.3134
# epoch:3960  d_loss:0.5226  g_loss:1.7900
# epoch:3961  d_loss:0.4431  g_loss:1.9663
# epoch:3962  d_loss:0.5538  g_loss:1.9865
# epoch:3963  d_loss:0.4916  g_loss:1.7561
# epoch:3964  d_loss:0.4520  g_loss:1.8123
# epoch:3965  d_loss:0.3210  g_loss:2.0085
# epoch:3966  d_loss:0.3163  g_loss:1.8316
# epoch:3967  d_loss:0.3335  g_loss:2.1283
# epoch:3968  d_loss:0.4894  g_loss:2.0348
# epoch:3969  d_loss:0.4643  g_loss:2.0730
# epoch:3970  d_loss:0.3616  g_loss:1.9040
# epoch:3971  d_loss:0.4665  g_loss:1.7727
# epoch:3972  d_loss:0.4689  g_loss:1.7543
# epoch:3973  d_loss:0.4786  g_loss:1.7999
# epoch:3974  d_loss:0.4625  g_loss:1.9644
# epoch:3975  d_loss:0.4615  g_loss:2.0127
# epoch:3976  d_loss:0.4222  g_loss:2.1666
# epoch:3977  d_loss:0.4609  g_loss:1.8686
# epoch:3978  d_loss:0.4059  g_loss:2.1491
# epoch:3979  d_loss:0.4763  g_loss:2.3527
# epoch:3980  d_loss:0.4516  g_loss:1.9798
# epoch:3981  d_loss:0.5299  g_loss:1.9996
# epoch:3982  d_loss:0.5112  g_loss:2.1148
# epoch:3983  d_loss:0.5494  g_loss:1.5086
# epoch:3984  d_loss:0.4751  g_loss:1.6758
# epoch:3985  d_loss:0.4798  g_loss:1.7233
# epoch:3986  d_loss:0.4413  g_loss:1.7337
# epoch:3987  d_loss:0.6952  g_loss:1.5611
# epoch:3988  d_loss:0.6247  g_loss:1.7525
# epoch:3989  d_loss:0.4991  g_loss:1.3412
# epoch:3990  d_loss:0.4837  g_loss:1.5170
# epoch:3991  d_loss:0.5064  g_loss:1.4015
# epoch:3992  d_loss:0.3763  g_loss:1.6774
# epoch:3993  d_loss:0.5237  g_loss:1.8985
# epoch:3994  d_loss:0.4786  g_loss:1.8839
# epoch:3995  d_loss:0.4477  g_loss:1.7160
# epoch:3996  d_loss:0.4254  g_loss:2.2723
# epoch:3997  d_loss:0.3374  g_loss:2.5085
# epoch:3998  d_loss:0.3580  g_loss:2.3539
# epoch:3999  d_loss:0.4747  g_loss:1.3615
# epoch:4000  d_loss:0.4875  g_loss:1.8051
# C:\Users\82108\anaconda3\envs\ts\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
