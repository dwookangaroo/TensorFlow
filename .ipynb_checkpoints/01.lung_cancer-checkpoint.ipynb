# %%
# 딥러닝을 구동하는 데 필요한 케라스 함수 호출
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 필요한 라이브러리 불러오기
import numpy as np
import tensorflow as tf

# 실행할 때마다 같은 결과를 출력하기 위해 설정하는 부분
np.random.seed(3)
tf.random.set_seed(3)

# 준비된 수술 환자 데이터를 불러오기
Data_set = np.loadtxt('data/dataset/ThoraricSurgery.csv', delimiter=',')

# 환자의 기록과 수술 결과를 X와 Y로 구분하여 저장
X = Data_set[:, 0:17]
y = Data_set[:, 17]

# 딥러닝 구조를 결정(모델을 설정하고 실행)
model = Sequential()
# add 하면서 layer을 쌓는 구조이다
# Dense (fully connected)

# 입력층
model.add(Dense(30, input_dim=17, activation='relu')) # 17개들어와서 30개로 나감
#출력층
model.add(Dense(1, activation='sigmoid')) # 이전층을 받아들이기때문에 30개를 그대로 받아쓴다

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 30)                540
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 31
# ...
# Total params: 571
# Trainable params: 571
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 0s 4ms/step - loss: 0.1485 - accuracy: 0.8426
# Epoch 2/100
# 47/47 [==============================] - 0s 5ms/step - loss: 0.1402 - accuracy: 0.8511
# Epoch 3/100
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1433 - accuracy: 0.8489: 0s - loss: 0.1713 - accura
# Epoch 4/100
# 47/47 [==============================] - 0s 8ms/step - loss: 0.1395 - accuracy: 0.8511
# Epoch 5/100
# 47/47 [==============================] - 1s 12ms/step - loss: 0.1386 - accuracy: 0.8468A: 0s - loss: 0.1396 -
# Epoch 6/100
# 47/47 [==============================] - 1s 13ms/step - loss: 0.1407 - accuracy: 0.8511
# Epoch 7/100
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1336 - accuracy: 0.8489
# Epoch 8/100
# 47/47 [==============================] - 1s 12ms/step - loss: 0.1384 - accuracy: 0.8511
# Epoch 9/100
# 47/47 [==============================] - 0s 7ms/step - loss: 0.1377 - accuracy: 0.8383
# Epoch 10/100
# ...
